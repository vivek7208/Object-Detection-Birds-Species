# %% [markdown]
# # Amazon SageMaker Object Detection for Bird Species
#
# 1. [Introduction](#Introduction)
# 2. [Setup](#Setup)
# 3. [Data Preparation](#Data-Preparation)
#   1. [Download and unpack the dataset](#Download-and-unpack-the-dataset)
#   2. [Understand the dataset](#Understand-the-dataset)
#   3. [Generate RecordIO files](#Generate-RecordIO-files)
# 4. [Train the model](#Train-the-model)
# 5. [Host the model](#Host-the-model)
# 6. [Test the model](#Test-the-model)
# 7. [Clean up](#Clean-up)
# 8. [Improve the model](#Improve-the-model)
# 9. [Final cleanup](#Final-cleanup)

# %% [markdown]
# ## Setup
#
# Before preparing the data, there are some initial steps required for setup.

# %% [markdown]
# This notebook requires two additional Python packages:
# * **OpenCV** is required for gathering image sizes and flipping of images horizontally.
# * The **MXNet** runtime is required for using the im2rec tool.

# %% [markdown]
# This solution relies on a config file to run the provisioned AWS resources. Run the cell below to generate that file.

# %%
import json
import os
import boto3

# %%
client = boto3.client("servicecatalog")
cwd = os.getcwd().split("/")
i = cwd.index("S3Downloads")
pp_name = cwd[i + 1]
pp = client.describe_provisioned_product(Name=pp_name)
record_id = pp["ProvisionedProductDetail"]["LastSuccessfulProvisioningRecordId"]
record = client.describe_record(Id=record_id)

keys = [x["OutputKey"] for x in record["RecordOutputs"] if "OutputKey" and "OutputValue" in x]
values = [x["OutputValue"] for x in record["RecordOutputs"] if "OutputKey" and "OutputValue" in x]
stack_output = dict(zip(keys, values))

with open(f"/root/S3Downloads/{pp_name}/stack_outputs.json", "w") as f:
    json.dump(stack_output, f)

# %%
import sagemaker

sess = sagemaker.Session()

role = sagemaker.get_execution_role()
sagemaker_config = json.load(open("stack_outputs.json"))
solution_bucket = sagemaker_config["SolutionS3Bucket"]
region = sagemaker_config["AWSRegion"]
library_version = sagemaker_config["LibraryVersion"]
solution_name = sagemaker_config["SolutionName"]
solution_prefix = sagemaker_config["SolutionPrefix"]
bucket = sagemaker_config["S3Bucket"]

# %% [markdown]
# ## Data Preparation
#
# The Caltech Birds (CUB 200 2011) dataset contains 11,788 images across 200 bird species (the original technical report can be found [here](https://authors.library.caltech.edu/27452/1/CUB_200_2011.pdf)).  Each species comes with around 60 images, with a typical size of about 350 pixels by 500 pixels.  Bounding boxes are provided, as are annotations of bird parts.  A recommended train/test split is given, but image size data is not.
#
# ## Download and unpack the dataset
#
# Here we download the birds dataset from CalTech.

# %%
import os
import urllib.request


def download(url):
    filename = url.split("/")[-1]
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url, filename)

# %%
# %%time
# download('http://www.vision.caltech.edu/visipedia-data/CUB-200-2011/CUB_200_2011.tgz')
# CalTech's download is (at least temporarily) unavailable since August 2020.

# Can now use one made available by fast.ai .
download("https://s3.amazonaws.com/fast-ai-imageclas/CUB_200_2011.tgz")
# Out:
# CPU times: user 1.89 s, sys: 1.47 s, total: 3.36 s
# Wall time: 28.7 s

# %% [markdown]
# Now we unpack the dataset into its own directory structure.

# %%
# %%time
# Clean up prior version of the downloaded dataset if you are running this again
# !rm -rf CUB_200_2011

# Unpack and then remove the downloaded compressed tar file
# !gunzip -c ./CUB_200_2011.tgz | tar xopf -
# !rm CUB_200_2011.tgz
# Out:
# CPU times: user 4.65 s, sys: 911 ms, total: 5.56 s
# Wall time: 4min 30s

# %% [markdown]
# ## Understand the dataset

# %% [markdown]
# ## Set some parameters for the rest of the notebook to use

# %% [markdown]
# Here we define a few parameters that help drive the rest of the notebook.  For example, `SAMPLE_ONLY` is defaulted to `True`. This will force the notebook to train on only a handful of species.  Setting to false will make the notebook work with the entire dataset of 200 bird species.  This makes the training a more difficult challenge, and you will need many more epochs to complete.
#
# The file parameters define names and locations of metadata files for the dataset.

# %%
import pandas as pd
import cv2
import boto3
import json

runtime = boto3.client(service_name="runtime.sagemaker")

import matplotlib.pyplot as plt

# %matplotlib inline

RANDOM_SPLIT = False
SAMPLE_ONLY = True
FLIP = False

# To speed up training and experimenting, you can use a small handful of species.
# To see the full list of the classes available, look at the content of CLASSES_FILE.
CLASSES = [17, 36, 47, 68, 73]

# Otherwise, you can use the full set of species
if not SAMPLE_ONLY:
    CLASSES = []
    for c in range(200):
        CLASSES += [c + 1]

RESIZE_SIZE = 256

BASE_DIR = "CUB_200_2011/"
IMAGES_DIR = BASE_DIR + "images/"

CLASSES_FILE = BASE_DIR + "classes.txt"
BBOX_FILE = BASE_DIR + "bounding_boxes.txt"
IMAGE_FILE = BASE_DIR + "images.txt"
LABEL_FILE = BASE_DIR + "image_class_labels.txt"
SIZE_FILE = BASE_DIR + "sizes.txt"
SPLIT_FILE = BASE_DIR + "train_test_split.txt"

TRAIN_LST_FILE = "birds_ssd_train.lst"
VAL_LST_FILE = "birds_ssd_val.lst"

if SAMPLE_ONLY:
    TRAIN_LST_FILE = "birds_ssd_sample_train.lst"
    VAL_LST_FILE = "birds_ssd_sample_val.lst"

TRAIN_RATIO = 0.8
CLASS_COLS = ["class_number", "class_id"]
IM2REC_SSD_COLS = [
    "header_cols",
    "label_width",
    "zero_based_id",
    "xmin",
    "ymin",
    "xmax",
    "ymax",
    "image_file_name",
]

# %% [markdown]
# ## Explore the dataset images
#
# For each species, there are dozens of images of various shapes and sizes. By dividing the entire dataset into individual named (numbered) folders, the images are in effect labelled for supervised learning using image classification and object detection algorithms.
#
# The following function displays a grid of thumbnail images for all the image files for a given species.

# %%
def show_species(species_id):
    _im_list = !ls $IMAGES_DIR/$species_id

    NUM_COLS = 6
    IM_COUNT = len(_im_list)

    print('Species ' + species_id + ' has ' + str(IM_COUNT) + ' images.')
    
    NUM_ROWS = int(IM_COUNT / NUM_COLS)
    if ((IM_COUNT % NUM_COLS) > 0):
        NUM_ROWS += 1

    fig, axarr = plt.subplots(NUM_ROWS, NUM_COLS)
    fig.set_size_inches(8.0, 16.0, forward=True)

    curr_row = 0
    for curr_img in range(IM_COUNT):
        # fetch the url as a file type object, then read the image
        f = IMAGES_DIR + species_id + '/' + _im_list[curr_img]
        a = plt.imread(f)

        # find the column by taking the current index modulo 3
        col = curr_img % NUM_ROWS
        # plot on relevant subplot
        axarr[col, curr_row].imshow(a)
        if col == (NUM_ROWS - 1):
            # we have finished the current row, so increment row counter
            curr_row += 1

    fig.tight_layout()       
    plt.show()
        
    # Clean up
    plt.clf()
    plt.cla()
    plt.close()

# %% [markdown]
# Show the list of bird species or dataset classes.

# %%
classes_df = pd.read_csv(CLASSES_FILE, sep=" ", names=CLASS_COLS, header=None)
criteria = classes_df["class_number"].isin(CLASSES)
classes_df = classes_df[criteria]
print(classes_df.to_csv(columns=["class_id"], sep="\t", index=False, header=False))
# Out:
# 017.Cardinal
# 036.Northern_Flicker
# 047.American_Goldfinch
# 068.Ruby_throated_Hummingbird
# 073.Blue_Jay

# %% [markdown]
# Now for any given species, display thumbnail images of each of the images provided for training and testing.

# %%
show_species("017.Cardinal")
# Out:
# Species 017.Cardinal has 57 images.

# %% [markdown]
# ## Generate RecordIO files

# %% [markdown]
# ### Step 1. Gather image sizes
#
# For this particular dataset, bounding box annotations are specified in absolute terms.  RecordIO format requires them to be defined in terms relative to the image size.  The following code visits each image, extracts the height and width, and saves this information into a file for subsequent use.  Some other publicly available datasets provide such a file for exactly this purpose.

# %%
# %%time
SIZE_COLS = ["idx", "width", "height"]


def gen_image_size_file():
    print("Generating a file containing image sizes...")
    images_df = pd.read_csv(
        IMAGE_FILE, sep=" ", names=["image_pretty_name", "image_file_name"], header=None
    )
    rows_list = []
    idx = 0
    for i in images_df["image_file_name"]:
        # TODO: add progress bar
        idx += 1
        img = cv2.imread(IMAGES_DIR + i)
        dimensions = img.shape
        height = img.shape[0]
        width = img.shape[1]
        image_dict = {"idx": idx, "width": width, "height": height}
        rows_list.append(image_dict)

    sizes_df = pd.DataFrame(rows_list)
    print("Image sizes:\n" + str(sizes_df.head()))

    sizes_df[SIZE_COLS].to_csv(SIZE_FILE, sep=" ", index=False, header=None)


gen_image_size_file()
# Out:
# Generating a file containing image sizes...
# Image sizes:
#    idx  width  height
# 0    1    500     335
# 1    2    500     336
# 2    3    500     347
# 3    4    415     500
# 4    5    331     380
# CPU times: user 41.6 s, sys: 1.48 s, total: 43.1 s
# Wall time: 1min 28s

# %% [markdown]
# ### Step 2. Generate list files for producing RecordIO files
#
# [RecordIO](https://mxnet.incubator.apache.org/architecture/note_data_loading.html) files can be created using the [im2rec tool](https://mxnet.incubator.apache.org/faq/recordio.html) (images to RecordIO), which takes as input a pair of list files, one for training images and the other for validation images.  Each list file has one row for each image.  For object detection, each row must contain bounding box data and a class label.
#
# For the CalTech birds dataset, we need to convert absolute bounding box dimensions to relative dimensions based on image size.  We also need to adjust class id's to be zero-based (instead of 1 to 200, they need to be 0 to 199).  This  dataset comes with recommended train/test split information ("is_training_image" flag).  This notebook is built flexibly to either leverage this suggestion, or to create a random train/test split with a specific train/test ratio.  The `RAMDOM_SPLIT` variable defined earlier controls whether or not the split happens randomly.

# %%
def split_to_train_test(df, label_column, train_frac=0.8):
    train_df, test_df = pd.DataFrame(), pd.DataFrame()
    labels = df[label_column].unique()
    for lbl in labels:
        lbl_df = df[df[label_column] == lbl]
        lbl_train_df = lbl_df.sample(frac=train_frac)
        lbl_test_df = lbl_df.drop(lbl_train_df.index)
        print(
            "\n{}:\n---------\ntotal:{}\ntrain_df:{}\ntest_df:{}".format(
                lbl, len(lbl_df), len(lbl_train_df), len(lbl_test_df)
            )
        )
        train_df = train_df.append(lbl_train_df)
        test_df = test_df.append(lbl_test_df)
    return train_df, test_df


def gen_list_files():
    # use generated sizes file
    sizes_df = pd.read_csv(
        SIZE_FILE, sep=" ", names=["image_pretty_name", "width", "height"], header=None
    )
    bboxes_df = pd.read_csv(
        BBOX_FILE,
        sep=" ",
        names=["image_pretty_name", "x_abs", "y_abs", "bbox_width", "bbox_height"],
        header=None,
    )
    split_df = pd.read_csv(
        SPLIT_FILE, sep=" ", names=["image_pretty_name", "is_training_image"], header=None
    )
    print(IMAGE_FILE)
    images_df = pd.read_csv(
        IMAGE_FILE, sep=" ", names=["image_pretty_name", "image_file_name"], header=None
    )
    print("num images total: " + str(images_df.shape[0]))
    image_class_labels_df = pd.read_csv(
        LABEL_FILE, sep=" ", names=["image_pretty_name", "class_id"], header=None
    )

    # Merge the metadata into a single flat dataframe for easier processing
    full_df = pd.DataFrame(images_df)
    full_df.reset_index(inplace=True)
    full_df = pd.merge(full_df, image_class_labels_df, on="image_pretty_name")
    full_df = pd.merge(full_df, sizes_df, on="image_pretty_name")
    full_df = pd.merge(full_df, bboxes_df, on="image_pretty_name")
    full_df = pd.merge(full_df, split_df, on="image_pretty_name")
    full_df.sort_values(by=["index"], inplace=True)

    # Define the bounding boxes in the format required by SageMaker's built in Object Detection algorithm.
    # the xmin/ymin/xmax/ymax parameters are specified as ratios to the total image pixel size
    full_df["header_cols"] = 2  # one col for the number of header cols, one for the label width
    full_df["label_width"] = 5  # number of cols for each label: class, xmin, ymin, xmax, ymax
    full_df["xmin"] = full_df["x_abs"] / full_df["width"]
    full_df["xmax"] = (full_df["x_abs"] + full_df["bbox_width"]) / full_df["width"]
    full_df["ymin"] = full_df["y_abs"] / full_df["height"]
    full_df["ymax"] = (full_df["y_abs"] + full_df["bbox_height"]) / full_df["height"]

    # object detection class id's must be zero based. map from
    # class_id's given by CUB to zero-based (1 is 0, and 200 is 199).

    if SAMPLE_ONLY:
        # grab a small subset of species for testing
        criteria = full_df["class_id"].isin(CLASSES)
        full_df = full_df[criteria]

    unique_classes = full_df["class_id"].drop_duplicates()
    sorted_unique_classes = sorted(unique_classes)

    id_to_zero = {}
    i = 0.0
    for c in sorted_unique_classes:
        id_to_zero[c] = i
        i += 1.0

    full_df["zero_based_id"] = full_df["class_id"].map(id_to_zero)

    full_df.reset_index(inplace=True)

    # use 4 decimal places, as it seems to be required by the Object Detection algorithm
    pd.set_option("display.precision", 4)

    train_df = []
    val_df = []

    if RANDOM_SPLIT:
        # split into training and validation sets
        train_df, val_df = split_to_train_test(full_df, "class_id", TRAIN_RATIO)

        train_df[IM2REC_SSD_COLS].to_csv(TRAIN_LST_FILE, sep="\t", float_format="%.4f", header=None)
        val_df[IM2REC_SSD_COLS].to_csv(VAL_LST_FILE, sep="\t", float_format="%.4f", header=None)
    else:
        train_df = full_df[(full_df.is_training_image == 1)]
        train_df[IM2REC_SSD_COLS].to_csv(TRAIN_LST_FILE, sep="\t", float_format="%.4f", header=None)

        val_df = full_df[(full_df.is_training_image == 0)]
        val_df[IM2REC_SSD_COLS].to_csv(VAL_LST_FILE, sep="\t", float_format="%.4f", header=None)

    print("num train: " + str(train_df.shape[0]))
    print("num val: " + str(val_df.shape[0]))
    return train_df, val_df

# %%
train_df, val_df = gen_list_files()
# Out:
# CUB_200_2011/images.txt
# num images total: 11788
# num train: 150
# num val: 147

# %% [markdown]
# Here we take a look at a few records from the training list file to understand better what is being fed to the RecordIO files.
#
# The first column is the image number or index.  The second column indicates that the label is made up of 2 columns (column 2 and column 3).  The third column specifies the label width of a single object. In our case, the value 5 indicates each image has 5 numbers to describe its label information: the class index, and the 4 bounding box coordinates. If there are multiple objects within one image, all the label information should be listed in one line. Our dataset contains only one bounding box per image.
#
# The fourth column is the class label.  This identifies the bird species using a zero-based class id.  Columns 4 through 7 represent the bounding box for where the bird is found in this image.
#
# The classes should be labeled with successive numbers and start with 0. The bounding box coordinates are ratios of its top-left (xmin, ymin) and bottom-right (xmax, ymax) corner indices to the overall image size. Note that the top-left corner of the entire image is the origin (0, 0). The last column specifies the relative path of the image file within the images directory.

# %%
# !tail -3 $TRAIN_LST_FILE
# Out:
# 291	2	5	4.0000	0.4080	0.1527	0.9880	0.8728	073.Blue_Jay/Blue_Jay_0048_62433.jpg
# 294	2	5	4.0000	0.2500	0.1455	0.8260	0.8303	073.Blue_Jay/Blue_Jay_0086_63394.jpg
# 296	2	5	4.0000	0.2960	0.5400	0.8160	0.8460	073.Blue_Jay/Blue_Jay_0074_63487.jpg

# %% [markdown]
# ### Step 3. Convert data into RecordIO format
#
# Now we create im2rec databases (.rec files) for training and validation based on the list files created earlier.

# %%
# !python tools/im2rec.py --resize $RESIZE_SIZE --pack-label birds_ssd_sample $BASE_DIR/images/
# Out:
# Creating .rec file from /root/S3Downloads/jumpstart-prod-odbs_d5sl79/birds_ssd_sample_train.lst in /root/S3Downloads/jumpstart-prod-odbs_d5sl79
# multiprocessing not available, fall back to single threaded encoding
# time: 0.013665437698364258  count: 0
# Creating .rec file from /root/S3Downloads/jumpstart-prod-odbs_d5sl79/birds_ssd_sample_val.lst in /root/S3Downloads/jumpstart-prod-odbs_d5sl79
# multiprocessing not available, fall back to single threaded encoding
# time: 0.008948802947998047  count: 0

# %% [markdown]
# ### Step 4. Upload RecordIO files to S3
# Upload the training and validation data to the S3 bucket. We do this in multiple channels. Channels are simply directories in the bucket that differentiate the types of data provided to the algorithm. For the object detection algorithm, we call these directories `train` and `validation`.

# %%
# Upload the RecordIO files to train and validation channels
train_channel = "train"
validation_channel = "validation"

sess.upload_data(path="birds_ssd_sample_train.rec", bucket=bucket, key_prefix=train_channel)
sess.upload_data(path="birds_ssd_sample_val.rec", bucket=bucket, key_prefix=validation_channel)

s3_train_data = "s3://{}/{}".format(bucket, train_channel)
s3_validation_data = "s3://{}/{}".format(bucket, validation_channel)

# %% [markdown]
# ## Train the model

# %% [markdown]
# Next we define an output location in S3, where the model artifacts will be placed on completion of the training. These artifacts are the output of the algorithm's traning job.  We also get the URI to the Amazon SageMaker Object Detection docker image.  This ensures the estimator uses the correct algorithm from the current region.

# %%
from sagemaker import image_uris

training_image = image_uris.retrieve(
    region=region, framework="object-detection", version="latest"
)
print(training_image)
# Out:
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: latest.
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/object-detection:1

# %%
s3_output_location = "s3://{}/output".format(bucket)

# %%
od_model = sagemaker.estimator.Estimator(
    training_image,
    role,
    instance_count=1,
    instance_type="ml.g4dn.4xlarge",
    volume_size=50,
    max_run=360000,
    input_mode="File",
    output_path=s3_output_location,
    sagemaker_session=sess,
    base_job_name=f"{solution_prefix}-training"
)

# %% [markdown]
# ## Define hyperparameters

# %% [markdown]
# The object detection algorithm at its core is the [Single-Shot Multi-Box detection algorithm (SSD)](https://arxiv.org/abs/1512.02325). This algorithm uses a `base_network`, which is typically a [VGG](https://arxiv.org/abs/1409.1556) or a [ResNet](https://arxiv.org/abs/1512.03385). The Amazon SageMaker object detection algorithm supports VGG-16 and ResNet-50. It also has a number of hyperparameters that help configure the training job. The next step in our training, is to setup these hyperparameters and data channels for training the model. See the SageMaker Object Detection [documentation](https://docs.aws.amazon.com/sagemaker/latest/dg/object-detection.html) for more details on its specific hyperparameters.
#
# One of the hyperparameters here for example is `epochs`. This defines how many passes of the dataset we iterate over and drives the training time of the algorithm. Based on our tests, we can achieve 70% accuracy on a sample mix of 5 species with 100 epochs.  When using the full 200 species, we can achieve 52% accuracy with 1,200 epochs.
#
# Note that Amazon SageMaker also provides [Automatic Model Tuning](https://docs.aws.amazon.com/sagemaker/latest/dg/automatic-model-tuning.html).  Automatic model tuning, also known as hyperparameter tuning, finds the best version of a model by running many training jobs on your dataset using the algorithm and ranges of hyperparameters that you specify. It then chooses the hyperparameter values that result in a model that performs the best, as measured by a metric that you choose.  When [tuning an Object Detection](https://docs.aws.amazon.com/sagemaker/latest/dg/object-detection-tuning.html) algorithm for example, the tuning job could find the best `validation:mAP` score by trying out various values for certain hyperparameters such as `mini_batch_size`, `weight_decay`, and `momentum`.

# %%
def set_hyperparameters(num_epochs, lr_steps):
    num_classes = classes_df.shape[0]
    num_training_samples = train_df.shape[0]
    print("num classes: {}, num training images: {}".format(num_classes, num_training_samples))

    od_model.set_hyperparameters(
        base_network="resnet-50",
        use_pretrained_model=1,
        num_classes=num_classes,
        mini_batch_size=16,
        epochs=num_epochs,
        learning_rate=0.001,
        lr_scheduler_step=lr_steps,
        lr_scheduler_factor=0.1,
        optimizer="sgd",
        momentum=0.9,
        weight_decay=0.0005,
        overlap_threshold=0.5,
        nms_threshold=0.45,
        image_shape=512,
        label_width=350,
        num_training_samples=num_training_samples,
    )

# %%
set_hyperparameters(100, "33,67")
# Out:
# num classes: 5, num training images: 150

# %% [markdown]
# Now that the hyperparameters are setup, we define the data channels to be passed to the algorithm. To do this, we need to create the `sagemaker.session.s3_input` objects from our data channels. These objects are then put in a simple dictionary, which the algorithm consumes.  Note that you could add a third channel named `model` to perform incremental training (continue training from where you had left off with a prior model).

# %%
train_data = sagemaker.inputs.TrainingInput(
    s3_train_data,
    distribution="FullyReplicated",
    content_type="application/x-recordio",
    s3_data_type="S3Prefix",
)
validation_data = sagemaker.inputs.TrainingInput(
    s3_validation_data,
    distribution="FullyReplicated",
    content_type="application/x-recordio",
    s3_data_type="S3Prefix",
)
data_channels = {"train": train_data, "validation": validation_data}

# %% [markdown]
# ## Submit training job

# %% [markdown]
# We have our `Estimator` object, we have set the hyperparameters for this object, and we have our data channels linked with the algorithm. The only remaining thing to do is to train the algorithm using the `fit` method. This will take more than 10 minutes in our example.
#
# The training process involves a few steps. First, the instances that we requested while creating the `Estimator` classes are provisioned and setup with the appropriate libraries. Then, the data from our channels are downloaded into the instance. Once this is done, the actual training begins. The provisioning and data downloading will take time, depending on the size of the data. Therefore it might be a few minutes before our training job logs show up in CloudWatch. The logs will also print out Mean Average Precision (mAP) on the validation data, among other losses, for every run of the dataset (once per epoch). This metric is a proxy for the accuracy of the model.
#
# Once the job has finished, a `Job complete` message will be printed. The trained model artifacts can be found in the S3 bucket that was setup as `output_path` in the estimator.

# %%
# %%time
od_model.fit(inputs=data_channels, logs=True)
# Out:
# 2023-06-26 18:13:13 Starting - Starting the training job...
# 2023-06-26 18:13:39 Starting - Preparing the instances for trainingProfilerReport-1687803193: InProgress
# ......
# 2023-06-26 18:14:39 Downloading - Downloading input data...
# 2023-06-26 18:14:59 Training - Downloading the training image..................
# 2023-06-26 18:18:06 Training - Training image download completed. Training in progress.....Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Mon Jun 26 18:18:47 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   33C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 525.85.12.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# Running custom environment configuration script
# [06/26/2023 18:18:50 INFO 139799461648192] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'base_network': 'vgg-16', 'use_pretrained_model': '0', 'num_classes': '', 'mini_batch_size': '32', 'epochs': '30', 'learning_rate': '0.001', 'lr_scheduler_step': '', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.9', 'weight_decay': '0.0005', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '', 'image_shape': '300', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# [06/26/2023 18:18:50 INFO 139799461648192] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'base_network': 'resnet-50', 'epochs': '100', 'image_shape': '512', 'label_width': '350', 'learning_rate': '0.001', 'lr_scheduler_factor': '0.1', 'lr_scheduler_step': '33,67', 'mini_batch_size': '16', 'momentum': '0.9', 'nms_threshold': '0.45', 'num_classes': '5', 'num_training_samples': '150', 'optimizer': 'sgd', 'overlap_threshold': '0.5', 'use_pretrained_model': '1', 'weight_decay': '0.0005'}
# [06/26/2023 18:18:50 INFO 139799461648192] Final configuration: {'base_network': 'resnet-50', 'use_pretrained_model': '1', 'num_classes': '5', 'mini_batch_size': '16', 'epochs': '100', 'learning_rate': '0.001', 'lr_scheduler_step': '33,67', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.9', 'weight_decay': '0.0005', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '150', 'image_shape': '512', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# Process 7 is a worker.
# [06/26/2023 18:18:50 INFO 139799461648192] Using default worker.
# [06/26/2023 18:18:50 INFO 139799461648192] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [06/26/2023 18:18:50 INFO 139799461648192] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [06/26/2023 18:18:50 INFO 139799461648192] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [06/26/2023 18:18:50 INFO 139799461648192] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [06/26/2023 18:18:50 INFO 139799461648192] Checkpoint loading and saving are disabled.
# [06/26/2023 18:18:50 INFO 139799461648192] nvidia-smi: took 0.030 seconds to run.
# [06/26/2023 18:18:50 INFO 139799461648192] nvidia-smi identified 1 GPUs.
# [06/26/2023 18:18:50 INFO 139799461648192] Number of GPUs being used: 1
# [06/26/2023 18:18:50 WARNING 139799461648192] Training images are resized to image shape (3, 512, 512)
# [18:18:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, use 15 threads for decoding..
# [18:18:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, label padding width: 350
# [06/26/2023 18:18:50 WARNING 139799461648192] Validation images are resized to image shape (3, 512, 512)
# [18:18:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, use 15 threads for decoding..
# [18:18:50] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, label padding width: 350
# [06/26/2023 18:18:51 INFO 139799461648192] Number of GPUs being used: 1
# [06/26/2023 18:18:51 INFO 139799461648192] Using [gpu(0)] as training context.
# [06/26/2023 18:18:51 INFO 139799461648192] Number of GPUs being used: 1
# [06/26/2023 18:18:51 INFO 139799461648192] Create Store: device
# [06/26/2023 18:18:51 INFO 139799461648192] Using (gpu(0)) as training context.
# [06/26/2023 18:18:51 INFO 139799461648192] Start training from pretrained model 1.
# [18:18:51] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [18:18:51] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [06/26/2023 18:18:51 INFO 139799461648192] Loaded pretrained model parameters.
# [06/26/2023 18:18:54 INFO 139799461648192] Creating a new state instance.
# #metrics {"StartTime": 1687803534.813842, "EndTime": 1687803534.813899, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [18:18:54] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [06/26/2023 18:19:07 INFO 139799461648192] #quality_metric: host=algo-1, epoch=0, batch=10 train cross_entropy <loss>=(2.1442043810005647)
# [06/26/2023 18:19:07 INFO 139799461648192] #quality_metric: host=algo-1, epoch=0, batch=10 train smooth_l1 <loss>=(0.6712807153602202)
# [06/26/2023 18:19:07 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:19:07 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:19:11 INFO 139799461648192] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(2.9562116643584026e-05)
# [06/26/2023 18:19:11 INFO 139799461648192] Updating the best model with validation-mAP=2.9562116643584026e-05
# [06/26/2023 18:19:11 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:19:11 INFO 139799461648192] #progress_metric: host=algo-1, completed 1.0 % of epochs
# #metrics {"StartTime": 1687803534.8141263, "EndTime": 1687803551.211624, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:19:17 INFO 139799461648192] #quality_metric: host=algo-1, epoch=1, batch=9 train cross_entropy <loss>=(1.8698867308591793)
# [06/26/2023 18:19:17 INFO 139799461648192] #quality_metric: host=algo-1, epoch=1, batch=9 train smooth_l1 <loss>=(0.685214285382288)
# [06/26/2023 18:19:17 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:19:17 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:19:21 INFO 139799461648192] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(8.60874533713339e-05)
# [06/26/2023 18:19:21 INFO 139799461648192] Updating the best model with validation-mAP=8.60874533713339e-05
# [06/26/2023 18:19:21 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:19:21 INFO 139799461648192] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1687803551.211767, "EndTime": 1687803561.2051485, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:19:28 INFO 139799461648192] #quality_metric: host=algo-1, epoch=2, batch=10 train cross_entropy <loss>=(1.8305547735990226)
# [06/26/2023 18:19:28 INFO 139799461648192] #quality_metric: host=algo-1, epoch=2, batch=10 train smooth_l1 <loss>=(0.6590703413060409)
# [06/26/2023 18:19:28 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:19:28 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:19:31 INFO 139799461648192] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(3.533651086253393e-05)
# [06/26/2023 18:19:31 INFO 139799461648192] #progress_metric: host=algo-1, completed 3.0 % of epochs
# #metrics {"StartTime": 1687803561.2052956, "EndTime": 1687803571.8807642, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:19:38 INFO 139799461648192] #quality_metric: host=algo-1, epoch=3, batch=9 train cross_entropy <loss>=(1.8098694965288815)
# [06/26/2023 18:19:38 INFO 139799461648192] #quality_metric: host=algo-1, epoch=3, batch=9 train smooth_l1 <loss>=(0.6718894904166733)
# [06/26/2023 18:19:38 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:19:38 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:19:41 INFO 139799461648192] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.00010579156662953689)
# [06/26/2023 18:19:41 INFO 139799461648192] Updating the best model with validation-mAP=0.00010579156662953689
# [06/26/2023 18:19:41 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:19:41 INFO 139799461648192] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1687803571.8809044, "EndTime": 1687803581.9551148, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:19:48 INFO 139799461648192] #quality_metric: host=algo-1, epoch=4, batch=9 train cross_entropy <loss>=(1.7912760216170822)
# [06/26/2023 18:19:48 INFO 139799461648192] #quality_metric: host=algo-1, epoch=4, batch=9 train smooth_l1 <loss>=(0.6633470226620243)
# [06/26/2023 18:19:48 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:19:48 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:19:52 INFO 139799461648192] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.0005499912268973268)
# [06/26/2023 18:19:52 INFO 139799461648192] Updating the best model with validation-mAP=0.0005499912268973268
# [06/26/2023 18:19:52 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:19:52 INFO 139799461648192] #progress_metric: host=algo-1, completed 5.0 % of epochs
# #metrics {"StartTime": 1687803581.955271, "EndTime": 1687803592.3556416, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:19:59 INFO 139799461648192] #quality_metric: host=algo-1, epoch=5, batch=10 train cross_entropy <loss>=(1.7805318196614583)
# [06/26/2023 18:19:59 INFO 139799461648192] #quality_metric: host=algo-1, epoch=5, batch=10 train smooth_l1 <loss>=(0.6363126405527894)
# [06/26/2023 18:19:59 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:19:59 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:20:03 INFO 139799461648192] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.0003098126500208771)
# [06/26/2023 18:20:03 INFO 139799461648192] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1687803592.3557804, "EndTime": 1687803603.108364, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:20:09 INFO 139799461648192] #quality_metric: host=algo-1, epoch=6, batch=9 train cross_entropy <loss>=(1.7655835993149702)
# [06/26/2023 18:20:09 INFO 139799461648192] #quality_metric: host=algo-1, epoch=6, batch=9 train smooth_l1 <loss>=(0.6374799584140297)
# [06/26/2023 18:20:09 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:20:09 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:20:13 INFO 139799461648192] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.0003949011635588402)
# [06/26/2023 18:20:13 INFO 139799461648192] #progress_metric: host=algo-1, completed 7.0 % of epochs
# #metrics {"StartTime": 1687803603.1085575, "EndTime": 1687803613.1117146, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 6, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:20:19 INFO 139799461648192] #quality_metric: host=algo-1, epoch=7, batch=9 train cross_entropy <loss>=(1.7597252124254001)
# [06/26/2023 18:20:19 INFO 139799461648192] #quality_metric: host=algo-1, epoch=7, batch=9 train smooth_l1 <loss>=(0.6383444514880026)
# [06/26/2023 18:20:19 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:20:19 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:20:23 INFO 139799461648192] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.0041421537030578975)
# [06/26/2023 18:20:23 INFO 139799461648192] Updating the best model with validation-mAP=0.0041421537030578975
# [06/26/2023 18:20:23 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:20:23 INFO 139799461648192] #progress_metric: host=algo-1, completed 8.0 % of epochs
# #metrics {"StartTime": 1687803613.1118786, "EndTime": 1687803623.2965817, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:20:31 INFO 139799461648192] #quality_metric: host=algo-1, epoch=8, batch=10 train cross_entropy <loss>=(1.7473439821055237)
# [06/26/2023 18:20:31 INFO 139799461648192] #quality_metric: host=algo-1, epoch=8, batch=10 train smooth_l1 <loss>=(0.6619265883181576)
# [06/26/2023 18:20:31 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:20:31 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:20:34 INFO 139799461648192] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.007977480302168289)
# [06/26/2023 18:20:34 INFO 139799461648192] Updating the best model with validation-mAP=0.007977480302168289
# [06/26/2023 18:20:34 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:20:34 INFO 139799461648192] #progress_metric: host=algo-1, completed 9.0 % of epochs
# #metrics {"StartTime": 1687803623.2967403, "EndTime": 1687803634.4947784, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:20:41 INFO 139799461648192] #quality_metric: host=algo-1, epoch=9, batch=9 train cross_entropy <loss>=(1.7280467137153903)
# [06/26/2023 18:20:41 INFO 139799461648192] #quality_metric: host=algo-1, epoch=9, batch=9 train smooth_l1 <loss>=(0.6368958507794791)
# [06/26/2023 18:20:41 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:20:41 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:20:44 INFO 139799461648192] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.008580251604786851)
# [06/26/2023 18:20:44 INFO 139799461648192] Updating the best model with validation-mAP=0.008580251604786851
# [06/26/2023 18:20:45 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:20:45 INFO 139799461648192] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1687803634.494922, "EndTime": 1687803645.1011243, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:20:52 INFO 139799461648192] #quality_metric: host=algo-1, epoch=10, batch=10 train cross_entropy <loss>=(1.7163174837799218)
# [06/26/2023 18:20:52 INFO 139799461648192] #quality_metric: host=algo-1, epoch=10, batch=10 train smooth_l1 <loss>=(0.6207676535007947)
# [06/26/2023 18:20:52 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:20:52 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:20:56 INFO 139799461648192] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.0087136617619035)
# [06/26/2023 18:20:56 INFO 139799461648192] Updating the best model with validation-mAP=0.0087136617619035
# [06/26/2023 18:20:56 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:20:56 INFO 139799461648192] #progress_metric: host=algo-1, completed 11.0 % of epochs
# #metrics {"StartTime": 1687803645.1012697, "EndTime": 1687803656.2896771, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:21:03 INFO 139799461648192] #quality_metric: host=algo-1, epoch=11, batch=9 train cross_entropy <loss>=(1.6968987874529602)
# [06/26/2023 18:21:03 INFO 139799461648192] #quality_metric: host=algo-1, epoch=11, batch=9 train smooth_l1 <loss>=(0.6262580880049727)
# [06/26/2023 18:21:03 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:21:03 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:21:06 INFO 139799461648192] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.009033502664860792)
# [06/26/2023 18:21:06 INFO 139799461648192] Updating the best model with validation-mAP=0.009033502664860792
# [06/26/2023 18:21:06 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:21:06 INFO 139799461648192] #progress_metric: host=algo-1, completed 12.0 % of epochs
# #metrics {"StartTime": 1687803656.2898188, "EndTime": 1687803666.700503, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:21:13 INFO 139799461648192] #quality_metric: host=algo-1, epoch=12, batch=9 train cross_entropy <loss>=(1.675043752403457)
# [06/26/2023 18:21:13 INFO 139799461648192] #quality_metric: host=algo-1, epoch=12, batch=9 train smooth_l1 <loss>=(0.6215262022660804)
# [06/26/2023 18:21:13 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:21:13 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:21:16 INFO 139799461648192] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.008703495061824662)
# [06/26/2023 18:21:16 INFO 139799461648192] #progress_metric: host=algo-1, completed 13.0 % of epochs
# #metrics {"StartTime": 1687803666.7006648, "EndTime": 1687803676.953208, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:21:24 INFO 139799461648192] #quality_metric: host=algo-1, epoch=13, batch=10 train cross_entropy <loss>=(1.6518899325666756)
# [06/26/2023 18:21:24 INFO 139799461648192] #quality_metric: host=algo-1, epoch=13, batch=10 train smooth_l1 <loss>=(0.6325396139502982)
# [06/26/2023 18:21:24 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:21:24 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:21:28 INFO 139799461648192] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.004542832257067486)
# [06/26/2023 18:21:28 INFO 139799461648192] #progress_metric: host=algo-1, completed 14.0 % of epochs
# #metrics {"StartTime": 1687803676.9533505, "EndTime": 1687803688.0005586, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:21:34 INFO 139799461648192] #quality_metric: host=algo-1, epoch=14, batch=9 train cross_entropy <loss>=(1.6275828916635087)
# [06/26/2023 18:21:34 INFO 139799461648192] #quality_metric: host=algo-1, epoch=14, batch=9 train smooth_l1 <loss>=(0.6492737727378731)
# [06/26/2023 18:21:34 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:21:34 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:21:38 INFO 139799461648192] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.009221588731630849)
# [06/26/2023 18:21:38 INFO 139799461648192] Updating the best model with validation-mAP=0.009221588731630849
# [06/26/2023 18:21:38 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:21:38 INFO 139799461648192] #progress_metric: host=algo-1, completed 15.0 % of epochs
# #metrics {"StartTime": 1687803688.000704, "EndTime": 1687803698.4012265, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:21:45 INFO 139799461648192] #quality_metric: host=algo-1, epoch=15, batch=9 train cross_entropy <loss>=(1.5804727368720077)
# [06/26/2023 18:21:45 INFO 139799461648192] #quality_metric: host=algo-1, epoch=15, batch=9 train smooth_l1 <loss>=(0.608833932975311)
# [06/26/2023 18:21:45 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:21:45 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:21:48 INFO 139799461648192] #quality_metric: host=algo-1, epoch=15, validation mAP <score>=(0.010722914650379634)
# [06/26/2023 18:21:48 INFO 139799461648192] Updating the best model with validation-mAP=0.010722914650379634
# [06/26/2023 18:21:49 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:21:49 INFO 139799461648192] #progress_metric: host=algo-1, completed 16.0 % of epochs
# #metrics {"StartTime": 1687803698.4013712, "EndTime": 1687803709.1260219, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 15, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:21:57 INFO 139799461648192] #quality_metric: host=algo-1, epoch=16, batch=10 train cross_entropy <loss>=(1.5500885099172592)
# [06/26/2023 18:21:57 INFO 139799461648192] #quality_metric: host=algo-1, epoch=16, batch=10 train smooth_l1 <loss>=(0.6237837225198746)
# [06/26/2023 18:21:57 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:21:57 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:22:00 INFO 139799461648192] #quality_metric: host=algo-1, epoch=16, validation mAP <score>=(0.005888007616357105)
# [06/26/2023 18:22:00 INFO 139799461648192] #progress_metric: host=algo-1, completed 17.0 % of epochs
# #metrics {"StartTime": 1687803709.1261399, "EndTime": 1687803720.453003, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 16, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:22:07 INFO 139799461648192] #quality_metric: host=algo-1, epoch=17, batch=9 train cross_entropy <loss>=(1.4870509406654446)
# [06/26/2023 18:22:07 INFO 139799461648192] #quality_metric: host=algo-1, epoch=17, batch=9 train smooth_l1 <loss>=(0.6224959072783884)
# [06/26/2023 18:22:07 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:22:07 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:22:10 INFO 139799461648192] #quality_metric: host=algo-1, epoch=17, validation mAP <score>=(0.013658511773298618)
# [06/26/2023 18:22:10 INFO 139799461648192] Updating the best model with validation-mAP=0.013658511773298618
# [06/26/2023 18:22:10 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:22:10 INFO 139799461648192] #progress_metric: host=algo-1, completed 18.0 % of epochs
# #metrics {"StartTime": 1687803720.4531512, "EndTime": 1687803730.9635668, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 17, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:22:18 INFO 139799461648192] #quality_metric: host=algo-1, epoch=18, batch=10 train cross_entropy <loss>=(1.4422818117363507)
# [06/26/2023 18:22:18 INFO 139799461648192] #quality_metric: host=algo-1, epoch=18, batch=10 train smooth_l1 <loss>=(0.587685226470001)
# [06/26/2023 18:22:18 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:22:18 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:22:22 INFO 139799461648192] #quality_metric: host=algo-1, epoch=18, validation mAP <score>=(0.03285144430627394)
# [06/26/2023 18:22:22 INFO 139799461648192] Updating the best model with validation-mAP=0.03285144430627394
# [06/26/2023 18:22:22 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:22:22 INFO 139799461648192] #progress_metric: host=algo-1, completed 19.0 % of epochs
# #metrics {"StartTime": 1687803730.963713, "EndTime": 1687803742.3036242, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 18, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:22:29 INFO 139799461648192] #quality_metric: host=algo-1, epoch=19, batch=9 train cross_entropy <loss>=(1.3831030344937683)
# [06/26/2023 18:22:29 INFO 139799461648192] #quality_metric: host=algo-1, epoch=19, batch=9 train smooth_l1 <loss>=(0.6001480720040643)
# [06/26/2023 18:22:29 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:22:29 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:22:32 INFO 139799461648192] #quality_metric: host=algo-1, epoch=19, validation mAP <score>=(0.04628782311432729)
# [06/26/2023 18:22:32 INFO 139799461648192] Updating the best model with validation-mAP=0.04628782311432729
# [06/26/2023 18:22:32 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:22:32 INFO 139799461648192] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1687803742.3037527, "EndTime": 1687803752.8672867, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 19, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 20.0, "count": 1, "min": 20, "max": 20}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:22:39 INFO 139799461648192] #quality_metric: host=algo-1, epoch=20, batch=9 train cross_entropy <loss>=(1.3476389262301862)
# [06/26/2023 18:22:39 INFO 139799461648192] #quality_metric: host=algo-1, epoch=20, batch=9 train smooth_l1 <loss>=(0.6216003008125243)
# [06/26/2023 18:22:39 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:22:39 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:22:43 INFO 139799461648192] #quality_metric: host=algo-1, epoch=20, validation mAP <score>=(0.039308732590282905)
# [06/26/2023 18:22:43 INFO 139799461648192] #progress_metric: host=algo-1, completed 21.0 % of epochs
# #metrics {"StartTime": 1687803752.867423, "EndTime": 1687803763.5618122, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 20, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 21.0, "count": 1, "min": 21, "max": 21}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:22:51 INFO 139799461648192] #quality_metric: host=algo-1, epoch=21, batch=10 train cross_entropy <loss>=(1.3070691165639394)
# [06/26/2023 18:22:51 INFO 139799461648192] #quality_metric: host=algo-1, epoch=21, batch=10 train smooth_l1 <loss>=(0.6131601760636515)
# [06/26/2023 18:22:51 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:22:51 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:22:54 INFO 139799461648192] #quality_metric: host=algo-1, epoch=21, validation mAP <score>=(0.06570269080318025)
# [06/26/2023 18:22:54 INFO 139799461648192] Updating the best model with validation-mAP=0.06570269080318025
# [06/26/2023 18:22:54 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:22:54 INFO 139799461648192] #progress_metric: host=algo-1, completed 22.0 % of epochs
# #metrics {"StartTime": 1687803763.5619612, "EndTime": 1687803774.9846253, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 21, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:23:02 INFO 139799461648192] #quality_metric: host=algo-1, epoch=22, batch=9 train cross_entropy <loss>=(1.277172008984273)
# [06/26/2023 18:23:02 INFO 139799461648192] #quality_metric: host=algo-1, epoch=22, batch=9 train smooth_l1 <loss>=(0.5884888993424513)
# [06/26/2023 18:23:02 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:23:02 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:23:05 INFO 139799461648192] #quality_metric: host=algo-1, epoch=22, validation mAP <score>=(0.09206025253377828)
# [06/26/2023 18:23:05 INFO 139799461648192] Updating the best model with validation-mAP=0.09206025253377828
# [06/26/2023 18:23:05 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:23:05 INFO 139799461648192] #progress_metric: host=algo-1, completed 23.0 % of epochs
# #metrics {"StartTime": 1687803774.9847631, "EndTime": 1687803785.5767412, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 22, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:23:12 INFO 139799461648192] #quality_metric: host=algo-1, epoch=23, batch=9 train cross_entropy <loss>=(1.233743852438386)
# [06/26/2023 18:23:12 INFO 139799461648192] #quality_metric: host=algo-1, epoch=23, batch=9 train smooth_l1 <loss>=(0.5604505322643162)
# [06/26/2023 18:23:12 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:23:12 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:23:15 INFO 139799461648192] #quality_metric: host=algo-1, epoch=23, validation mAP <score>=(0.09868955944129716)
# [06/26/2023 18:23:15 INFO 139799461648192] Updating the best model with validation-mAP=0.09868955944129716
# [06/26/2023 18:23:16 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:23:16 INFO 139799461648192] #progress_metric: host=algo-1, completed 24.0 % of epochs
# #metrics {"StartTime": 1687803785.5768864, "EndTime": 1687803796.0255597, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 23, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:23:23 INFO 139799461648192] #quality_metric: host=algo-1, epoch=24, batch=10 train cross_entropy <loss>=(1.1760262121422014)
# [06/26/2023 18:23:23 INFO 139799461648192] #quality_metric: host=algo-1, epoch=24, batch=10 train smooth_l1 <loss>=(0.5658683919728026)
# [06/26/2023 18:23:23 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:23:23 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:23:27 INFO 139799461648192] #quality_metric: host=algo-1, epoch=24, validation mAP <score>=(0.11321030710349364)
# [06/26/2023 18:23:27 INFO 139799461648192] Updating the best model with validation-mAP=0.11321030710349364
# [06/26/2023 18:23:27 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:23:27 INFO 139799461648192] #progress_metric: host=algo-1, completed 25.0 % of epochs
# #metrics {"StartTime": 1687803796.0256748, "EndTime": 1687803807.2785778, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 24, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:23:34 INFO 139799461648192] #quality_metric: host=algo-1, epoch=25, batch=9 train cross_entropy <loss>=(1.1549891081236234)
# [06/26/2023 18:23:34 INFO 139799461648192] #quality_metric: host=algo-1, epoch=25, batch=9 train smooth_l1 <loss>=(0.5698528270312301)
# [06/26/2023 18:23:34 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:23:34 INFO 139799461648192] Updated the metrics
# ...
# [06/26/2023 18:34:49 INFO 139799461648192] #progress_metric: host=algo-1, completed 90.0 % of epochs
# #metrics {"StartTime": 1687804478.53267, "EndTime": 1687804489.1145484, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 89, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 90.0, "count": 1, "min": 90, "max": 90}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:34:56 INFO 139799461648192] #quality_metric: host=algo-1, epoch=90, batch=10 train cross_entropy <loss>=(0.9530374949215022)
# [06/26/2023 18:34:56 INFO 139799461648192] #quality_metric: host=algo-1, epoch=90, batch=10 train smooth_l1 <loss>=(0.5175410263410961)
# [06/26/2023 18:34:56 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:34:57 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:35:00 INFO 139799461648192] #quality_metric: host=algo-1, epoch=90, validation mAP <score>=(0.15304771839687176)
# [06/26/2023 18:35:00 INFO 139799461648192] #progress_metric: host=algo-1, completed 91.0 % of epochs
# #metrics {"StartTime": 1687804489.1147068, "EndTime": 1687804500.2365346, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 90, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 91.0, "count": 1, "min": 91, "max": 91}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:35:07 INFO 139799461648192] #quality_metric: host=algo-1, epoch=91, batch=9 train cross_entropy <loss>=(0.9640388886133829)
# [06/26/2023 18:35:07 INFO 139799461648192] #quality_metric: host=algo-1, epoch=91, batch=9 train smooth_l1 <loss>=(0.5146857420603435)
# [06/26/2023 18:35:07 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:35:07 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:35:10 INFO 139799461648192] #quality_metric: host=algo-1, epoch=91, validation mAP <score>=(0.15970685822442346)
# [06/26/2023 18:35:10 INFO 139799461648192] #progress_metric: host=algo-1, completed 92.0 % of epochs
# #metrics {"StartTime": 1687804500.2366996, "EndTime": 1687804510.5315979, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 91, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:35:17 INFO 139799461648192] #quality_metric: host=algo-1, epoch=92, batch=9 train cross_entropy <loss>=(0.9610828280328622)
# [06/26/2023 18:35:17 INFO 139799461648192] #quality_metric: host=algo-1, epoch=92, batch=9 train smooth_l1 <loss>=(0.5312370854598122)
# [06/26/2023 18:35:17 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:35:17 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:35:20 INFO 139799461648192] #quality_metric: host=algo-1, epoch=92, validation mAP <score>=(0.16110374681827194)
# [06/26/2023 18:35:20 INFO 139799461648192] #progress_metric: host=algo-1, completed 93.0 % of epochs
# #metrics {"StartTime": 1687804510.5317664, "EndTime": 1687804520.8172178, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 92, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 93.0, "count": 1, "min": 93, "max": 93}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:35:28 INFO 139799461648192] #quality_metric: host=algo-1, epoch=93, batch=10 train cross_entropy <loss>=(0.9494159882738253)
# [06/26/2023 18:35:28 INFO 139799461648192] #quality_metric: host=algo-1, epoch=93, batch=10 train smooth_l1 <loss>=(0.5182622796947499)
# [06/26/2023 18:35:28 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:35:28 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:35:31 INFO 139799461648192] #quality_metric: host=algo-1, epoch=93, validation mAP <score>=(0.16305184244271356)
# [06/26/2023 18:35:31 INFO 139799461648192] #progress_metric: host=algo-1, completed 94.0 % of epochs
# #metrics {"StartTime": 1687804520.8173766, "EndTime": 1687804531.934966, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 93, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 94.0, "count": 1, "min": 94, "max": 94}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:35:38 INFO 139799461648192] #quality_metric: host=algo-1, epoch=94, batch=9 train cross_entropy <loss>=(0.9688112432306463)
# [06/26/2023 18:35:38 INFO 139799461648192] #quality_metric: host=algo-1, epoch=94, batch=9 train smooth_l1 <loss>=(0.5526114993625217)
# [06/26/2023 18:35:38 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:35:38 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:35:42 INFO 139799461648192] #quality_metric: host=algo-1, epoch=94, validation mAP <score>=(0.15502491552779107)
# [06/26/2023 18:35:42 INFO 139799461648192] #progress_metric: host=algo-1, completed 95.0 % of epochs
# #metrics {"StartTime": 1687804531.9351451, "EndTime": 1687804542.205089, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 94, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 95.0, "count": 1, "min": 95, "max": 95}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:35:49 INFO 139799461648192] #quality_metric: host=algo-1, epoch=95, batch=9 train cross_entropy <loss>=(0.9740609244565126)
# [06/26/2023 18:35:49 INFO 139799461648192] #quality_metric: host=algo-1, epoch=95, batch=9 train smooth_l1 <loss>=(0.5341112394149095)
# [06/26/2023 18:35:49 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:35:49 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:35:52 INFO 139799461648192] #quality_metric: host=algo-1, epoch=95, validation mAP <score>=(0.17456450055522685)
# [06/26/2023 18:35:52 INFO 139799461648192] Updating the best model with validation-mAP=0.17456450055522685
# [06/26/2023 18:35:52 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:35:52 INFO 139799461648192] #progress_metric: host=algo-1, completed 96.0 % of epochs
# #metrics {"StartTime": 1687804542.205243, "EndTime": 1687804552.9286876, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 95, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 96.0, "count": 1, "min": 96, "max": 96}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:36:00 INFO 139799461648192] #quality_metric: host=algo-1, epoch=96, batch=10 train cross_entropy <loss>=(0.9630331529575087)
# [06/26/2023 18:36:00 INFO 139799461648192] #quality_metric: host=algo-1, epoch=96, batch=10 train smooth_l1 <loss>=(0.5193616593538051)
# [06/26/2023 18:36:00 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:36:00 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:36:04 INFO 139799461648192] #quality_metric: host=algo-1, epoch=96, validation mAP <score>=(0.16534855522688716)
# [06/26/2023 18:36:04 INFO 139799461648192] #progress_metric: host=algo-1, completed 97.0 % of epochs
# #metrics {"StartTime": 1687804552.928818, "EndTime": 1687804564.1666214, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 96, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 97.0, "count": 1, "min": 97, "max": 97}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:36:11 INFO 139799461648192] #quality_metric: host=algo-1, epoch=97, batch=9 train cross_entropy <loss>=(0.9525059996666639)
# [06/26/2023 18:36:11 INFO 139799461648192] #quality_metric: host=algo-1, epoch=97, batch=9 train smooth_l1 <loss>=(0.5143547456299338)
# [06/26/2023 18:36:11 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:36:11 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:36:14 INFO 139799461648192] #quality_metric: host=algo-1, epoch=97, validation mAP <score>=(0.167126643612012)
# [06/26/2023 18:36:14 INFO 139799461648192] #progress_metric: host=algo-1, completed 98.0 % of epochs
# #metrics {"StartTime": 1687804564.1667755, "EndTime": 1687804574.464226, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 97, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 98.0, "count": 1, "min": 98, "max": 98}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:36:22 INFO 139799461648192] #quality_metric: host=algo-1, epoch=98, batch=10 train cross_entropy <loss>=(0.9611299501048575)
# [06/26/2023 18:36:22 INFO 139799461648192] #quality_metric: host=algo-1, epoch=98, batch=10 train smooth_l1 <loss>=(0.5425144614075585)
# [06/26/2023 18:36:22 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:36:22 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:36:25 INFO 139799461648192] #quality_metric: host=algo-1, epoch=98, validation mAP <score>=(0.15566180057068743)
# [06/26/2023 18:36:25 INFO 139799461648192] #progress_metric: host=algo-1, completed 99.0 % of epochs
# #metrics {"StartTime": 1687804574.4643617, "EndTime": 1687804585.577376, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 98, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 99.0, "count": 1, "min": 99, "max": 99}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# 2023-06-26 18:36:43 Uploading - Uploading generated training model[06/26/2023 18:36:32 INFO 139799461648192] #quality_metric: host=algo-1, epoch=99, batch=9 train cross_entropy <loss>=(0.9587965939295431)
# [06/26/2023 18:36:32 INFO 139799461648192] #quality_metric: host=algo-1, epoch=99, batch=9 train smooth_l1 <loss>=(0.5326814131977957)
# [06/26/2023 18:36:32 INFO 139799461648192] Round of batches complete
# [06/26/2023 18:36:32 INFO 139799461648192] Updated the metrics
# [06/26/2023 18:36:35 INFO 139799461648192] #quality_metric: host=algo-1, epoch=99, validation mAP <score>=(0.1577127804093951)
# [06/26/2023 18:36:35 INFO 139799461648192] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1687804585.5775404, "EndTime": 1687804595.8589618, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 99, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:36:35 WARNING 139799461648192] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/26/2023 18:36:36 INFO 139799461648192] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:36:36 INFO 139799461648192] Test data is not provided.
# #metrics {"StartTime": 1687803530.2045112, "EndTime": 1687804596.1651123, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "setuptime": {"sum": 5.010366439819336, "count": 1, "min": 5.010366439819336, "max": 5.010366439819336}, "totaltime": {"sum": 1066020.7259654999, "count": 1, "min": 1066020.7259654999, "max": 1066020.7259654999}}}
#
# 2023-06-26 18:37:03 Completed - Training job completed
# Training seconds: 1336
# Billable seconds: 1336
# CPU times: user 2.49 s, sys: 245 ms, total: 2.74 s
# Wall time: 24min 14s

# %% [markdown]
# Now that the training job is complete, you can also see the job listed in the `Training jobs` section of your SageMaker console.  Note that the job name is uniquely identified by the name of the algorithm concatenated with the date and time stamp.  You can click on the job to see the details including the hyperparameters, the data channel definitions, and the full path to the resulting model artifacts.  You could even clone the job from the console, and tweak some of the parameters to generate a new training job.

# %% [markdown]
# Without having to go to the CloudWatch console, you can see how the job progressed in terms of the key object detection algorithm metric, mean average precision (mAP).  This function below prepares a simple chart of that metric against the epochs.

# %%
import boto3
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %matplotlib inline

client = boto3.client("logs")
BASE_LOG_NAME = "/aws/sagemaker/TrainingJobs"


def plot_object_detection_log(model, title):
    logs = client.describe_log_streams(
        logGroupName=BASE_LOG_NAME, logStreamNamePrefix=model._current_job_name
    )
    cw_log = client.get_log_events(
        logGroupName=BASE_LOG_NAME, logStreamName=logs["logStreams"][0]["logStreamName"]
    )

    mAP_accs = []
    for e in cw_log["events"]:
        msg = e["message"]
        if "validation mAP <score>=" in msg:
            num_start = msg.find("(")
            num_end = msg.find(")")
            mAP = msg[num_start + 1 : num_end]
            mAP_accs.append(float(mAP))

    print(title)
    print("Maximum mAP: %f " % max(mAP_accs))

    fig, ax = plt.subplots()
    plt.xlabel("Epochs")
    plt.ylabel("Mean Avg Precision (mAP)")
    (val_plot,) = ax.plot(range(len(mAP_accs)), mAP_accs, label="mAP")
    plt.legend(handles=[val_plot])
    ax.yaxis.set_ticks(np.arange(0.0, 1.05, 0.1))
    ax.yaxis.set_major_formatter(ticker.FormatStrFormatter("%0.2f"))
    plt.show()

# %%
plot_object_detection_log(od_model, "mAP tracking for job: " + od_model._current_job_name)
# Out:
# mAP tracking for job: sagemaker-soln-odbs-js-d5sl79-training-2023-06-26-18-13-13-811
# Maximum mAP: 0.174565

# %% [markdown]
# ## Host the model

# %% [markdown]
# Once the training is done, we can deploy the trained model as an Amazon SageMaker real-time hosted endpoint. This lets us make predictions (or inferences) from the model. Note that we don't have to host using the same type of instance that we used to train. Training is a prolonged and compute heavy job with different compute and memory requirements that hosting typically does not. In our case we chose the `ml.p3.2xlarge` instance to train, but we choose to host the model on the less expensive cpu instance, `ml.m4.xlarge`. The endpoint deployment takes several minutes, and can be accomplished with a single line of code calling the `deploy` method.
#
# Note that some use cases require large sets of inferences on a predefined body of images.  In those cases, you do not need to make the inferences in real time.  Instead, you could use SageMaker's [batch transform jobs](https://docs.aws.amazon.com/sagemaker/latest/dg/how-it-works-batch.html).

# %%
# %%time
object_detector = od_model.deploy(
    endpoint_name=f"{solution_prefix}-od-endpoint",
    model_name=f"{solution_prefix}-od-model",
    initial_instance_count=1,
    instance_type="ml.m5.xlarge",
)
# Out:
# ----------!CPU times: user 71.6 ms, sys: 7.15 ms, total: 78.7 ms
# Wall time: 5min 2s

# %% [markdown]
# ## Test the model

# %% [markdown]
# Now that the trained model is deployed at an endpoint that is up-and-running, we can use this endpoint for inference.  The results of a call to the inference endpoint are in a format that is similar to the .lst format, with the addition of a confidence score for each detected object. The format of the output can be represented as `[class_index, confidence_score, xmin, ymin, xmax, ymax]`. Typically, we don't visualize low-confidence predictions.
#
# We have provided a script to easily visualize the detection outputs. You can visulize the high-confidence preditions with bounding box by filtering out low-confidence detections using the script below:

# %%
def visualize_detection(img_file, dets, classes=[], thresh=0.6):
    """
    visualize detections in one image
    Parameters:
    ----------
    img : numpy.array
        image, in bgr format
    dets : numpy.array
        ssd detections, numpy.array([[id, score, x1, y1, x2, y2]...])
        each row is one object
    classes : tuple or list of str
        class names
    thresh : float
        score threshold
    """
    import random
    import matplotlib.pyplot as plt
    import matplotlib.image as mpimg

    img = mpimg.imread(img_file)
    plt.imshow(img)
    height = img.shape[0]
    width = img.shape[1]
    colors = dict()
    num_detections = 0
    for det in dets:
        (klass, score, x0, y0, x1, y1) = det
        if score < thresh:
            continue
        num_detections += 1
        cls_id = int(klass)
        if cls_id not in colors:
            colors[cls_id] = (random.random(), random.random(), random.random())
        xmin = int(x0 * width)
        ymin = int(y0 * height)
        xmax = int(x1 * width)
        ymax = int(y1 * height)
        rect = plt.Rectangle(
            (xmin, ymin),
            xmax - xmin,
            ymax - ymin,
            fill=False,
            edgecolor=colors[cls_id],
            linewidth=3.5,
        )
        plt.gca().add_patch(rect)
        class_name = str(cls_id)
        if classes and len(classes) > cls_id:
            class_name = classes[cls_id]
        print("{},{}".format(class_name, score))
        plt.gca().text(
            xmin,
            ymin - 2,
            "{:s} {:.3f}".format(class_name, score),
            bbox=dict(facecolor=colors[cls_id], alpha=0.5),
            fontsize=12,
            color="white",
        )

    print("Number of detections: " + str(num_detections))
    plt.show()

# %% [markdown]
# Now we use our endpoint to try to detect objects within an image. Since the image is a jpeg, we use the appropriate content_type to run the prediction. The endpoint returns a JSON object that we can simply load and peek into. We have packaged the prediction code into a function to make it easier to test other images.  Note that we are defaulting the confidence threshold to 30% in our example, as a couple of the birds in our sample images were not being detected as clearly.  Defining an appropriate threshold is entirely dependent on your use case.

# %%
OBJECT_CATEGORIES = classes_df["class_id"].values.tolist()


def show_bird_prediction(filename, ep, thresh=0.40):
    b = ""
    with open(filename, "rb") as image:
        f = image.read()
        b = bytearray(f)
    endpoint_response = runtime.invoke_endpoint(EndpointName=ep, ContentType="image/jpeg", Body=b)
    results = endpoint_response["Body"].read()
    detections = json.loads(results)
    visualize_detection(filename, detections["prediction"], OBJECT_CATEGORIES, thresh)

# %% [markdown]
# Here we download images that the algorithm has not yet seen.

# %%
from sagemaker.s3 import S3Downloader

test_images_bucket = f"s3://{solution_bucket}-{region}/{library_version}/{solution_name}"
test_images_prefix = f"artifacts/test_images"
test_data = f"{test_images_bucket}/{test_images_prefix}"
print("test data: ")
S3Downloader.list(test_data)
# Out:
# test data:
# ['s3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/blue-jay-1.jpg',
#  's3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/hummingbird-1.jpg',
#  's3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/multi-goldfinch-1.jpg',
#  's3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/northern-cardinal-1.jpg',
#  's3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/northern-flicker-1.jpg']

# %%
# !aws s3 cp --recursive --no-progress $test_data test_images
# Out:
# download: s3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/multi-goldfinch-1.jpg to test_images/multi-goldfinch-1.jpg
# download: s3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/hummingbird-1.jpg to test_images/hummingbird-1.jpg
# download: s3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/blue-jay-1.jpg to test_images/blue-jay-1.jpg
# download: s3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/northern-cardinal-1.jpg to test_images/northern-cardinal-1.jpg
# download: s3://sagemaker-solutions-prod-us-east-1/0.2.0/Object-Detection-for-Bird-Species/1.0.0/artifacts/test_images/northern-flicker-1.jpg to test_images/northern-flicker-1.jpg

# %%
def test_model():
    show_bird_prediction("test_images/hummingbird-1.jpg", object_detector.endpoint_name)
    show_bird_prediction("test_images/blue-jay-1.jpg", object_detector.endpoint_name)
    show_bird_prediction("test_images/multi-goldfinch-1.jpg", object_detector.endpoint_name)
    show_bird_prediction("test_images/northern-flicker-1.jpg", object_detector.endpoint_name)
    show_bird_prediction("test_images/northern-cardinal-1.jpg", object_detector.endpoint_name)

test_model()
# Out:
# Number of detections: 0
# Number of detections: 0
# Number of detections: 0
# Number of detections: 0
# Number of detections: 0

# %% [markdown]
# ## Clean up
# Here we delete the SageMaker endpoint, as we will no longer be performing any inferences.  This is an important step, as your account is billed for the amount of time an endpoint is running, even when it is idle.

# %%
sagemaker.Session().delete_endpoint(object_detector.endpoint_name)

# %% [markdown]
# ## Improve the model

# %% [markdown]
# ### Define Function to Flip the Images Horizontally (on the X Axis)

# %%
from PIL import Image


def flip_images():
    print("Flipping images...")

    SIZE_COLS = ["idx", "width", "height"]
    IMAGE_COLS = ["image_pretty_name", "image_file_name"]
    LABEL_COLS = ["image_pretty_name", "class_id"]
    BBOX_COLS = ["image_pretty_name", "x_abs", "y_abs", "bbox_width", "bbox_height"]
    SPLIT_COLS = ["image_pretty_name", "is_training_image"]

    images_df = pd.read_csv(BASE_DIR + "images.txt", sep=" ", names=IMAGE_COLS, header=None)
    image_class_labels_df = pd.read_csv(
        BASE_DIR + "image_class_labels.txt", sep=" ", names=LABEL_COLS, header=None
    )
    bboxes_df = pd.read_csv(BASE_DIR + "bounding_boxes.txt", sep=" ", names=BBOX_COLS, header=None)
    split_df = pd.read_csv(
        BASE_DIR + "train_test_split.txt", sep=" ", names=SPLIT_COLS, header=None
    )

    NUM_ORIGINAL_IMAGES = images_df.shape[0]

    rows_list = []
    bbox_rows_list = []
    size_rows_list = []
    label_rows_list = []
    split_rows_list = []

    idx = 0

    full_df = images_df.copy()
    full_df.reset_index(inplace=True)
    full_df = pd.merge(full_df, image_class_labels_df, on="image_pretty_name")
    full_df = pd.merge(full_df, bboxes_df, on="image_pretty_name")
    full_df = pd.merge(full_df, split_df, on="image_pretty_name")
    full_df.sort_values(by=["index"], inplace=True)

    if SAMPLE_ONLY:
        # grab a small subset of species for testing
        criteria = full_df["class_id"].isin(CLASSES)
        full_df = full_df[criteria]

    for rel_image_fn in full_df["image_file_name"]:
        idx += 1
        full_img_content = full_df[(full_df.image_file_name == rel_image_fn)]

        class_id = full_img_content.iloc[0].class_id

        img = Image.open(IMAGES_DIR + rel_image_fn)

        width, height = img.size

        new_idx = idx + NUM_ORIGINAL_IMAGES

        flip_core_file_name = rel_image_fn[:-4] + "_flip.jpg"
        flip_full_file_name = IMAGES_DIR + flip_core_file_name

        img_flip = img.transpose(Image.FLIP_LEFT_RIGHT)
        img_flip.save(flip_full_file_name)

        # append a new image
        dict = {"image_pretty_name": new_idx, "image_file_name": flip_core_file_name}
        rows_list.append(dict)

        # append a new split, use same flag for flipped image from original image
        is_training_image = full_img_content.iloc[0].is_training_image
        split_dict = {"image_pretty_name": new_idx, "is_training_image": is_training_image}
        split_rows_list.append(split_dict)

        # append a new image class label
        label_dict = {"image_pretty_name": new_idx, "class_id": class_id}
        label_rows_list.append(label_dict)

        # add a size row for the original and the flipped image, same height and width
        size_dict = {"idx": idx, "width": width, "height": height}
        size_rows_list.append(size_dict)

        size_dict = {"idx": new_idx, "width": width, "height": height}
        size_rows_list.append(size_dict)

        # append bounding box for flipped image

        x_abs = full_img_content.iloc[0].x_abs
        y_abs = full_img_content.iloc[0].y_abs
        bbox_width = full_img_content.iloc[0].bbox_width
        bbox_height = full_img_content.iloc[0].bbox_height
        flipped_x_abs = width - bbox_width - x_abs

        bbox_dict = {
            "image_pretty_name": new_idx,
            "x_abs": flipped_x_abs,
            "y_abs": y_abs,
            "bbox_width": bbox_width,
            "bbox_height": bbox_height,
        }
        bbox_rows_list.append(bbox_dict)

    print("Done looping through original images")

    images_df = images_df.append(rows_list)
    images_df[IMAGE_COLS].to_csv(IMAGE_FILE, sep=" ", index=False, header=None)
    bboxes_df = bboxes_df.append(bbox_rows_list)
    bboxes_df[BBOX_COLS].to_csv(BBOX_FILE, sep=" ", index=False, header=None)
    split_df = split_df.append(split_rows_list)
    split_df[SPLIT_COLS].to_csv(SPLIT_FILE, sep=" ", index=False, header=None)
    sizes_df = pd.DataFrame(size_rows_list)
    sizes_df[SIZE_COLS].to_csv(SIZE_FILE, sep=" ", index=False, header=None)
    image_class_labels_df = image_class_labels_df.append(label_rows_list)
    image_class_labels_df[LABEL_COLS].to_csv(LABEL_FILE, sep=" ", index=False, header=None)

    print("Done saving metadata in text files")

# %% [markdown]
# ### Re-train the model with the expanded dataset

# %%
# %%time

BBOX_FILE = BASE_DIR + "bounding_boxes_with_flip.txt"
IMAGE_FILE = BASE_DIR + "images_with_flip.txt"
LABEL_FILE = BASE_DIR + "image_class_labels_with_flip.txt"
SIZE_FILE = BASE_DIR + "sizes_with_flip.txt"
SPLIT_FILE = BASE_DIR + "train_test_split_with_flip.txt"

# add a set of flipped images
flip_images()

# show the new full set of images for a species
show_species("017.Cardinal")

# create new sizes file
gen_image_size_file()

# re-create and re-deploy the RecordIO files with the updated set of images
train_df, val_df = gen_list_files()
# !python tools/im2rec.py --resize $RESIZE_SIZE --pack-label birds_ssd_sample $BASE_DIR/images/
sess.upload_data(path="birds_ssd_sample_train.rec", bucket=bucket, key_prefix=train_channel)
sess.upload_data(path="birds_ssd_sample_val.rec", bucket=bucket, key_prefix=validation_channel)

# account for the new number of training images
set_hyperparameters(100, "33,67")

# re-train
od_model.fit(inputs=data_channels, logs=True)

# check out the new accuracy
plot_object_detection_log(od_model, "mAP tracking for job: " + od_model._current_job_name)
# Out:
# Flipping images...
# Done looping through original images
# Done saving metadata in text files
# Species 017.Cardinal has 114 images.
# Generating a file containing image sizes...
# Image sizes:
#    idx  width  height
# 0    1    500     335
# 1    2    500     336
# 2    3    500     347
# 3    4    415     500
# 4    5    331     380
# CUB_200_2011/images_with_flip.txt
# num images total: 12085
# num train: 300
# num val: 294
# Creating .rec file from /root/S3Downloads/jumpstart-prod-odbs_d5sl79/birds_ssd_sample_train.lst in /root/S3Downloads/jumpstart-prod-odbs_d5sl79
# multiprocessing not available, fall back to single threaded encoding
# time: 0.01373291015625  count: 0
# Creating .rec file from /root/S3Downloads/jumpstart-prod-odbs_d5sl79/birds_ssd_sample_val.lst in /root/S3Downloads/jumpstart-prod-odbs_d5sl79
# multiprocessing not available, fall back to single threaded encoding
# time: 0.008711099624633789  count: 0
# num classes: 5, num training images: 300
# 2023-06-26 18:44:14 Starting - Starting the training job...
# 2023-06-26 18:44:38 Starting - Preparing the instances for trainingProfilerReport-1687805054: InProgress
# ......
# 2023-06-26 18:45:38 Downloading - Downloading input data...
# 2023-06-26 18:45:58 Training - Downloading the training image...............
# 2023-06-26 18:48:39 Training - Training image download completed. Training in progress......Docker entrypoint called with argument(s): train
# Running default environment configuration script
# Nvidia gpu devices, drivers and cuda toolkit versions (only available on hosts with GPU):
# Mon Jun 26 18:49:17 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            On   | 00000000:00:1E.0 Off |                    0 |
# | N/A   32C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
# Checking for nvidia driver and cuda compatibility.
# CUDA Compatibility driver provided.
# Proceeding with compatibility check between driver, cuda-toolkit and cuda-compat.
# Detected cuda-toolkit version: 11.1.
# Detected cuda-compat version: 455.32.00.
# Detected Nvidia driver version: 525.85.12.
# Nvidia driver compatible with cuda-toolkit. Disabling cuda-compat.
# Running custom environment configuration script
# [06/26/2023 18:49:20 INFO 139767272523584] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'base_network': 'vgg-16', 'use_pretrained_model': '0', 'num_classes': '', 'mini_batch_size': '32', 'epochs': '30', 'learning_rate': '0.001', 'lr_scheduler_step': '', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.9', 'weight_decay': '0.0005', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '', 'image_shape': '300', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# [06/26/2023 18:49:20 INFO 139767272523584] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'base_network': 'resnet-50', 'epochs': '100', 'image_shape': '512', 'label_width': '350', 'learning_rate': '0.001', 'lr_scheduler_factor': '0.1', 'lr_scheduler_step': '33,67', 'mini_batch_size': '16', 'momentum': '0.9', 'nms_threshold': '0.45', 'num_classes': '5', 'num_training_samples': '300', 'optimizer': 'sgd', 'overlap_threshold': '0.5', 'use_pretrained_model': '1', 'weight_decay': '0.0005'}
# [06/26/2023 18:49:20 INFO 139767272523584] Final configuration: {'base_network': 'resnet-50', 'use_pretrained_model': '1', 'num_classes': '5', 'mini_batch_size': '16', 'epochs': '100', 'learning_rate': '0.001', 'lr_scheduler_step': '33,67', 'lr_scheduler_factor': '0.1', 'optimizer': 'sgd', 'momentum': '0.9', 'weight_decay': '0.0005', 'overlap_threshold': '0.5', 'nms_threshold': '0.45', 'num_training_samples': '300', 'image_shape': '512', '_tuning_objective_metric': '', '_kvstore': 'device', 'kv_store': 'device', '_num_kv_servers': 'auto', 'label_width': '350', 'freeze_layer_pattern': '', 'nms_topk': '400', 'early_stopping': 'False', 'early_stopping_min_epochs': '10', 'early_stopping_patience': '5', 'early_stopping_tolerance': '0.0', '_begin_epoch': '0'}
# Process 7 is a worker.
# [06/26/2023 18:49:20 INFO 139767272523584] Using default worker.
# [06/26/2023 18:49:20 INFO 139767272523584] Loaded iterator creator application/x-image for content type ('application/x-image', '1.0')
# [06/26/2023 18:49:20 INFO 139767272523584] Loaded iterator creator application/x-recordio for content type ('application/x-recordio', '1.0')
# [06/26/2023 18:49:20 INFO 139767272523584] Loaded iterator creator image/jpeg for content type ('image/jpeg', '1.0')
# [06/26/2023 18:49:20 INFO 139767272523584] Loaded iterator creator image/png for content type ('image/png', '1.0')
# [06/26/2023 18:49:20 INFO 139767272523584] Checkpoint loading and saving are disabled.
# [06/26/2023 18:49:20 INFO 139767272523584] nvidia-smi: took 0.030 seconds to run.
# [06/26/2023 18:49:20 INFO 139767272523584] nvidia-smi identified 1 GPUs.
# [06/26/2023 18:49:20 INFO 139767272523584] Number of GPUs being used: 1
# [06/26/2023 18:49:20 WARNING 139767272523584] Training images are resized to image shape (3, 512, 512)
# [18:49:20] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, use 15 threads for decoding..
# [18:49:20] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/train/birds_ssd_sample_train.rec, label padding width: 350
# [06/26/2023 18:49:21 WARNING 139767272523584] Validation images are resized to image shape (3, 512, 512)
# [18:49:21] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:283: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, use 15 threads for decoding..
# [18:49:21] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/io/iter_image_det_recordio.cc:340: ImageDetRecordIOParser: /opt/ml/input/data/validation/birds_ssd_sample_val.rec, label padding width: 350
# [06/26/2023 18:49:21 INFO 139767272523584] Number of GPUs being used: 1
# [06/26/2023 18:49:21 INFO 139767272523584] Using [gpu(0)] as training context.
# [06/26/2023 18:49:21 INFO 139767272523584] Number of GPUs being used: 1
# [06/26/2023 18:49:21 INFO 139767272523584] Create Store: device
# [06/26/2023 18:49:21 INFO 139767272523584] Using (gpu(0)) as training context.
# [06/26/2023 18:49:21 INFO 139767272523584] Start training from pretrained model 1.
# [18:49:21] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v0.8.0. Attempting to upgrade...
# [18:49:21] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# [06/26/2023 18:49:22 INFO 139767272523584] Loaded pretrained model parameters.
# [06/26/2023 18:49:25 INFO 139767272523584] Creating a new state instance.
# #metrics {"StartTime": 1687805365.611908, "EndTime": 1687805365.6119585, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [18:49:25] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.4.x_ecl_Cuda_11.1.x.205.0/AL2_x86_64/generic-flavor/src/src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [06/26/2023 18:49:45 INFO 139767272523584] #quality_metric: host=algo-1, epoch=0, batch=19 train cross_entropy <loss>=(2.0204906503442435)
# [06/26/2023 18:49:45 INFO 139767272523584] #quality_metric: host=algo-1, epoch=0, batch=19 train smooth_l1 <loss>=(0.6830417975503368)
# [06/26/2023 18:49:45 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:49:45 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:49:51 INFO 139767272523584] #quality_metric: host=algo-1, epoch=0, validation mAP <score>=(3.080013138454745e-05)
# [06/26/2023 18:49:51 INFO 139767272523584] Updating the best model with validation-mAP=3.080013138454745e-05
# [06/26/2023 18:49:52 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:49:52 INFO 139767272523584] #progress_metric: host=algo-1, completed 1.0 % of epochs
# #metrics {"StartTime": 1687805365.6121902, "EndTime": 1687805392.0200157, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:50:06 INFO 139767272523584] #quality_metric: host=algo-1, epoch=1, batch=19 train cross_entropy <loss>=(1.8224952103894243)
# [06/26/2023 18:50:06 INFO 139767272523584] #quality_metric: host=algo-1, epoch=1, batch=19 train smooth_l1 <loss>=(0.6667906894031349)
# [06/26/2023 18:50:06 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:50:06 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:50:12 INFO 139767272523584] #quality_metric: host=algo-1, epoch=1, validation mAP <score>=(9.071318497791052e-05)
# [06/26/2023 18:50:12 INFO 139767272523584] Updating the best model with validation-mAP=9.071318497791052e-05
# [06/26/2023 18:50:12 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:50:12 INFO 139767272523584] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1687805392.0201607, "EndTime": 1687805412.3818154, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:50:26 INFO 139767272523584] #quality_metric: host=algo-1, epoch=2, batch=19 train cross_entropy <loss>=(1.7942036058775772)
# [06/26/2023 18:50:26 INFO 139767272523584] #quality_metric: host=algo-1, epoch=2, batch=19 train smooth_l1 <loss>=(0.6537199114436464)
# [06/26/2023 18:50:26 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:50:26 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:50:33 INFO 139767272523584] #quality_metric: host=algo-1, epoch=2, validation mAP <score>=(0.00024616810302411176)
# [06/26/2023 18:50:33 INFO 139767272523584] Updating the best model with validation-mAP=0.00024616810302411176
# [06/26/2023 18:50:33 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:50:33 INFO 139767272523584] #progress_metric: host=algo-1, completed 3.0 % of epochs
# #metrics {"StartTime": 1687805412.3819885, "EndTime": 1687805433.1758058, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:50:46 INFO 139767272523584] #quality_metric: host=algo-1, epoch=3, batch=18 train cross_entropy <loss>=(1.7639742550923352)
# [06/26/2023 18:50:46 INFO 139767272523584] #quality_metric: host=algo-1, epoch=3, batch=18 train smooth_l1 <loss>=(0.6363751699616791)
# [06/26/2023 18:50:46 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:50:46 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:50:52 INFO 139767272523584] #quality_metric: host=algo-1, epoch=3, validation mAP <score>=(0.0004746696825187265)
# [06/26/2023 18:50:52 INFO 139767272523584] Updating the best model with validation-mAP=0.0004746696825187265
# [06/26/2023 18:50:52 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:50:52 INFO 139767272523584] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1687805433.175958, "EndTime": 1687805452.9931428, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:51:07 INFO 139767272523584] #quality_metric: host=algo-1, epoch=4, batch=19 train cross_entropy <loss>=(1.7394985427856446)
# [06/26/2023 18:51:07 INFO 139767272523584] #quality_metric: host=algo-1, epoch=4, batch=19 train smooth_l1 <loss>=(0.646390531539917)
# [06/26/2023 18:51:07 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:51:07 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:51:13 INFO 139767272523584] #quality_metric: host=algo-1, epoch=4, validation mAP <score>=(0.002047046508414967)
# [06/26/2023 18:51:13 INFO 139767272523584] Updating the best model with validation-mAP=0.002047046508414967
# [06/26/2023 18:51:13 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:51:13 INFO 139767272523584] #progress_metric: host=algo-1, completed 5.0 % of epochs
# #metrics {"StartTime": 1687805452.9932888, "EndTime": 1687805473.9884474, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 4, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:51:28 INFO 139767272523584] #quality_metric: host=algo-1, epoch=5, batch=19 train cross_entropy <loss>=(1.707978540983446)
# [06/26/2023 18:51:28 INFO 139767272523584] #quality_metric: host=algo-1, epoch=5, batch=19 train smooth_l1 <loss>=(0.6310258972838364)
# [06/26/2023 18:51:28 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:51:28 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:51:35 INFO 139767272523584] #quality_metric: host=algo-1, epoch=5, validation mAP <score>=(0.005153604548682957)
# [06/26/2023 18:51:35 INFO 139767272523584] Updating the best model with validation-mAP=0.005153604548682957
# [06/26/2023 18:51:35 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:51:35 INFO 139767272523584] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1687805473.9885914, "EndTime": 1687805495.217619, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:51:50 INFO 139767272523584] #quality_metric: host=algo-1, epoch=6, batch=19 train cross_entropy <loss>=(1.67467472801788)
# [06/26/2023 18:51:50 INFO 139767272523584] #quality_metric: host=algo-1, epoch=6, batch=19 train smooth_l1 <loss>=(0.6150681669016419)
# [06/26/2023 18:51:50 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:51:50 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:51:56 INFO 139767272523584] #quality_metric: host=algo-1, epoch=6, validation mAP <score>=(0.006370261778518738)
# [06/26/2023 18:51:56 INFO 139767272523584] Updating the best model with validation-mAP=0.006370261778518738
# [06/26/2023 18:51:56 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:51:56 INFO 139767272523584] #progress_metric: host=algo-1, completed 7.0 % of epochs
# #metrics {"StartTime": 1687805495.217771, "EndTime": 1687805516.4564993, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 6, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 7.0, "count": 1, "min": 7, "max": 7}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:52:10 INFO 139767272523584] #quality_metric: host=algo-1, epoch=7, batch=18 train cross_entropy <loss>=(1.6137722904818046)
# [06/26/2023 18:52:10 INFO 139767272523584] #quality_metric: host=algo-1, epoch=7, batch=18 train smooth_l1 <loss>=(0.6195303348679617)
# [06/26/2023 18:52:10 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:52:10 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:52:16 INFO 139767272523584] #quality_metric: host=algo-1, epoch=7, validation mAP <score>=(0.01603072978712015)
# [06/26/2023 18:52:16 INFO 139767272523584] Updating the best model with validation-mAP=0.01603072978712015
# [06/26/2023 18:52:17 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:52:17 INFO 139767272523584] #progress_metric: host=algo-1, completed 8.0 % of epochs
# #metrics {"StartTime": 1687805516.4566581, "EndTime": 1687805537.0328865, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 7, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:52:32 INFO 139767272523584] #quality_metric: host=algo-1, epoch=8, batch=19 train cross_entropy <loss>=(1.5270396130167951)
# [06/26/2023 18:52:32 INFO 139767272523584] #quality_metric: host=algo-1, epoch=8, batch=19 train smooth_l1 <loss>=(0.6104936239037679)
# [06/26/2023 18:52:32 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:52:32 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:52:39 INFO 139767272523584] #quality_metric: host=algo-1, epoch=8, validation mAP <score>=(0.02265886587024109)
# [06/26/2023 18:52:39 INFO 139767272523584] Updating the best model with validation-mAP=0.02265886587024109
# [06/26/2023 18:52:39 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:52:39 INFO 139767272523584] #progress_metric: host=algo-1, completed 9.0 % of epochs
# #metrics {"StartTime": 1687805537.0330312, "EndTime": 1687805559.3131516, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 8, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 9.0, "count": 1, "min": 9, "max": 9}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:52:54 INFO 139767272523584] #quality_metric: host=algo-1, epoch=9, batch=19 train cross_entropy <loss>=(1.4229459272009295)
# [06/26/2023 18:52:54 INFO 139767272523584] #quality_metric: host=algo-1, epoch=9, batch=19 train smooth_l1 <loss>=(0.5948375091624744)
# [06/26/2023 18:52:54 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:52:54 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:53:00 INFO 139767272523584] #quality_metric: host=algo-1, epoch=9, validation mAP <score>=(0.033750533731207656)
# [06/26/2023 18:53:00 INFO 139767272523584] Updating the best model with validation-mAP=0.033750533731207656
# [06/26/2023 18:53:00 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:53:00 INFO 139767272523584] #progress_metric: host=algo-1, completed 10.0 % of epochs
# #metrics {"StartTime": 1687805559.313329, "EndTime": 1687805580.4113197, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 9, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 10.0, "count": 1, "min": 10, "max": 10}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:53:15 INFO 139767272523584] #quality_metric: host=algo-1, epoch=10, batch=19 train cross_entropy <loss>=(1.3300475123870652)
# [06/26/2023 18:53:15 INFO 139767272523584] #quality_metric: host=algo-1, epoch=10, batch=19 train smooth_l1 <loss>=(0.6067315725527062)
# [06/26/2023 18:53:15 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:53:15 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:53:21 INFO 139767272523584] #quality_metric: host=algo-1, epoch=10, validation mAP <score>=(0.0472670636860831)
# [06/26/2023 18:53:21 INFO 139767272523584] Updating the best model with validation-mAP=0.0472670636860831
# [06/26/2023 18:53:21 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:53:21 INFO 139767272523584] #progress_metric: host=algo-1, completed 11.0 % of epochs
# #metrics {"StartTime": 1687805580.4114542, "EndTime": 1687805601.6356351, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 11.0, "count": 1, "min": 11, "max": 11}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:53:35 INFO 139767272523584] #quality_metric: host=algo-1, epoch=11, batch=18 train cross_entropy <loss>=(1.2384718751150465)
# [06/26/2023 18:53:35 INFO 139767272523584] #quality_metric: host=algo-1, epoch=11, batch=18 train smooth_l1 <loss>=(0.6007256205119784)
# [06/26/2023 18:53:35 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:53:35 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:53:41 INFO 139767272523584] #quality_metric: host=algo-1, epoch=11, validation mAP <score>=(0.06204420198401796)
# [06/26/2023 18:53:41 INFO 139767272523584] Updating the best model with validation-mAP=0.06204420198401796
# [06/26/2023 18:53:41 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:53:41 INFO 139767272523584] #progress_metric: host=algo-1, completed 12.0 % of epochs
# #metrics {"StartTime": 1687805601.6357903, "EndTime": 1687805621.5051994, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 11, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:53:56 INFO 139767272523584] #quality_metric: host=algo-1, epoch=12, batch=19 train cross_entropy <loss>=(1.1784220326097705)
# [06/26/2023 18:53:56 INFO 139767272523584] #quality_metric: host=algo-1, epoch=12, batch=19 train smooth_l1 <loss>=(0.5797686439224436)
# [06/26/2023 18:53:56 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:53:56 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:54:02 INFO 139767272523584] #quality_metric: host=algo-1, epoch=12, validation mAP <score>=(0.07451040164980563)
# [06/26/2023 18:54:02 INFO 139767272523584] Updating the best model with validation-mAP=0.07451040164980563
# [06/26/2023 18:54:02 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:54:02 INFO 139767272523584] #progress_metric: host=algo-1, completed 13.0 % of epochs
# #metrics {"StartTime": 1687805621.5053225, "EndTime": 1687805642.4572887, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 12, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:54:17 INFO 139767272523584] #quality_metric: host=algo-1, epoch=13, batch=19 train cross_entropy <loss>=(1.1188005080951258)
# [06/26/2023 18:54:17 INFO 139767272523584] #quality_metric: host=algo-1, epoch=13, batch=19 train smooth_l1 <loss>=(0.5742664656615609)
# [06/26/2023 18:54:17 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:54:17 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:54:23 INFO 139767272523584] #quality_metric: host=algo-1, epoch=13, validation mAP <score>=(0.10613734751489663)
# [06/26/2023 18:54:23 INFO 139767272523584] Updating the best model with validation-mAP=0.10613734751489663
# [06/26/2023 18:54:23 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:54:23 INFO 139767272523584] #progress_metric: host=algo-1, completed 14.0 % of epochs
# #metrics {"StartTime": 1687805642.4574287, "EndTime": 1687805663.4516385, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 13, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 14.0, "count": 1, "min": 14, "max": 14}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:54:38 INFO 139767272523584] #quality_metric: host=algo-1, epoch=14, batch=19 train cross_entropy <loss>=(1.082799080090645)
# [06/26/2023 18:54:38 INFO 139767272523584] #quality_metric: host=algo-1, epoch=14, batch=19 train smooth_l1 <loss>=(0.5729871387970753)
# [06/26/2023 18:54:38 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:54:38 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:54:43 INFO 139767272523584] #quality_metric: host=algo-1, epoch=14, validation mAP <score>=(0.10034010240655036)
# [06/26/2023 18:54:43 INFO 139767272523584] #progress_metric: host=algo-1, completed 15.0 % of epochs
# #metrics {"StartTime": 1687805663.4517715, "EndTime": 1687805683.9730313, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 14, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:54:57 INFO 139767272523584] #quality_metric: host=algo-1, epoch=15, batch=18 train cross_entropy <loss>=(1.044884766789673)
# [06/26/2023 18:54:57 INFO 139767272523584] #quality_metric: host=algo-1, epoch=15, batch=18 train smooth_l1 <loss>=(0.5640373721818692)
# [06/26/2023 18:54:57 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:54:57 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:55:03 INFO 139767272523584] #quality_metric: host=algo-1, epoch=15, validation mAP <score>=(0.1312041784343269)
# [06/26/2023 18:55:03 INFO 139767272523584] Updating the best model with validation-mAP=0.1312041784343269
# [06/26/2023 18:55:03 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:55:03 INFO 139767272523584] #progress_metric: host=algo-1, completed 16.0 % of epochs
# #metrics {"StartTime": 1687805683.973168, "EndTime": 1687805703.8387897, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 15, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 16.0, "count": 1, "min": 16, "max": 16}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:55:18 INFO 139767272523584] #quality_metric: host=algo-1, epoch=16, batch=19 train cross_entropy <loss>=(1.00059010447388)
# [06/26/2023 18:55:18 INFO 139767272523584] #quality_metric: host=algo-1, epoch=16, batch=19 train smooth_l1 <loss>=(0.5384753226744069)
# [06/26/2023 18:55:18 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:55:18 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:55:25 INFO 139767272523584] #quality_metric: host=algo-1, epoch=16, validation mAP <score>=(0.09176337261885247)
# [06/26/2023 18:55:25 INFO 139767272523584] #progress_metric: host=algo-1, completed 17.0 % of epochs
# #metrics {"StartTime": 1687805703.8389115, "EndTime": 1687805725.0080986, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 16, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 17.0, "count": 1, "min": 17, "max": 17}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:55:39 INFO 139767272523584] #quality_metric: host=algo-1, epoch=17, batch=19 train cross_entropy <loss>=(0.9825009711834465)
# [06/26/2023 18:55:39 INFO 139767272523584] #quality_metric: host=algo-1, epoch=17, batch=19 train smooth_l1 <loss>=(0.5342802610314749)
# [06/26/2023 18:55:39 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:55:39 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:55:45 INFO 139767272523584] #quality_metric: host=algo-1, epoch=17, validation mAP <score>=(0.15037457511418126)
# [06/26/2023 18:55:45 INFO 139767272523584] Updating the best model with validation-mAP=0.15037457511418126
# [06/26/2023 18:55:45 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:55:45 INFO 139767272523584] #progress_metric: host=algo-1, completed 18.0 % of epochs
# #metrics {"StartTime": 1687805725.0082448, "EndTime": 1687805745.8767934, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 17, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:56:00 INFO 139767272523584] #quality_metric: host=algo-1, epoch=18, batch=19 train cross_entropy <loss>=(0.9672090892150076)
# [06/26/2023 18:56:00 INFO 139767272523584] #quality_metric: host=algo-1, epoch=18, batch=19 train smooth_l1 <loss>=(0.5239588246003759)
# [06/26/2023 18:56:00 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:56:00 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:56:07 INFO 139767272523584] #quality_metric: host=algo-1, epoch=18, validation mAP <score>=(0.12684209510622713)
# [06/26/2023 18:56:07 INFO 139767272523584] #progress_metric: host=algo-1, completed 19.0 % of epochs
# #metrics {"StartTime": 1687805745.8769467, "EndTime": 1687805767.0180607, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 18, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 19.0, "count": 1, "min": 19, "max": 19}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:56:21 INFO 139767272523584] #quality_metric: host=algo-1, epoch=19, batch=18 train cross_entropy <loss>=(0.9530599481342384)
# [06/26/2023 18:56:21 INFO 139767272523584] #quality_metric: host=algo-1, epoch=19, batch=18 train smooth_l1 <loss>=(0.5149940529948335)
# [06/26/2023 18:56:21 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:56:21 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:56:27 INFO 139767272523584] #quality_metric: host=algo-1, epoch=19, validation mAP <score>=(0.10641679414120539)
# [06/26/2023 18:56:27 INFO 139767272523584] #progress_metric: host=algo-1, completed 20.0 % of epochs
# #metrics {"StartTime": 1687805767.0182118, "EndTime": 1687805787.2114909, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 19, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 20.0, "count": 1, "min": 20, "max": 20}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:56:42 INFO 139767272523584] #quality_metric: host=algo-1, epoch=20, batch=19 train cross_entropy <loss>=(0.9407414430313221)
# [06/26/2023 18:56:42 INFO 139767272523584] #quality_metric: host=algo-1, epoch=20, batch=19 train smooth_l1 <loss>=(0.519575132927271)
# [06/26/2023 18:56:42 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:56:42 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:56:48 INFO 139767272523584] #quality_metric: host=algo-1, epoch=20, validation mAP <score>=(0.1470717842236059)
# [06/26/2023 18:56:48 INFO 139767272523584] #progress_metric: host=algo-1, completed 21.0 % of epochs
# #metrics {"StartTime": 1687805787.211639, "EndTime": 1687805808.6643472, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 20, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 21.0, "count": 1, "min": 21, "max": 21}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:57:03 INFO 139767272523584] #quality_metric: host=algo-1, epoch=21, batch=19 train cross_entropy <loss>=(0.9355733271405976)
# [06/26/2023 18:57:03 INFO 139767272523584] #quality_metric: host=algo-1, epoch=21, batch=19 train smooth_l1 <loss>=(0.49062642175470594)
# [06/26/2023 18:57:03 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:57:03 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:57:09 INFO 139767272523584] #quality_metric: host=algo-1, epoch=21, validation mAP <score>=(0.16454100863190796)
# [06/26/2023 18:57:09 INFO 139767272523584] Updating the best model with validation-mAP=0.16454100863190796
# [06/26/2023 18:57:09 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:57:09 INFO 139767272523584] #progress_metric: host=algo-1, completed 22.0 % of epochs
# #metrics {"StartTime": 1687805808.6644907, "EndTime": 1687805829.9413893, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 21, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 22.0, "count": 1, "min": 22, "max": 22}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:57:24 INFO 139767272523584] #quality_metric: host=algo-1, epoch=22, batch=19 train cross_entropy <loss>=(0.9211539418304561)
# [06/26/2023 18:57:24 INFO 139767272523584] #quality_metric: host=algo-1, epoch=22, batch=19 train smooth_l1 <loss>=(0.505524019628649)
# [06/26/2023 18:57:24 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:57:24 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:57:30 INFO 139767272523584] #quality_metric: host=algo-1, epoch=22, validation mAP <score>=(0.20324147646078336)
# [06/26/2023 18:57:30 INFO 139767272523584] Updating the best model with validation-mAP=0.20324147646078336
# [06/26/2023 18:57:30 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:57:30 INFO 139767272523584] #progress_metric: host=algo-1, completed 23.0 % of epochs
# #metrics {"StartTime": 1687805829.9415238, "EndTime": 1687805850.5709062, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 22, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 23.0, "count": 1, "min": 23, "max": 23}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:57:44 INFO 139767272523584] #quality_metric: host=algo-1, epoch=23, batch=18 train cross_entropy <loss>=(0.9248798652412883)
# [06/26/2023 18:57:44 INFO 139767272523584] #quality_metric: host=algo-1, epoch=23, batch=18 train smooth_l1 <loss>=(0.49525666299388865)
# [06/26/2023 18:57:44 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:57:44 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:57:50 INFO 139767272523584] #quality_metric: host=algo-1, epoch=23, validation mAP <score>=(0.24459485978621348)
# [06/26/2023 18:57:50 INFO 139767272523584] Updating the best model with validation-mAP=0.24459485978621348
# [06/26/2023 18:57:50 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 18:57:50 INFO 139767272523584] #progress_metric: host=algo-1, completed 24.0 % of epochs
# #metrics {"StartTime": 1687805850.5710835, "EndTime": 1687805870.251421, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 23, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 24.0, "count": 1, "min": 24, "max": 24}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 18:58:05 INFO 139767272523584] #quality_metric: host=algo-1, epoch=24, batch=19 train cross_entropy <loss>=(0.9231410793762829)
# [06/26/2023 18:58:05 INFO 139767272523584] #quality_metric: host=algo-1, epoch=24, batch=19 train smooth_l1 <loss>=(0.47820323936322556)
# [06/26/2023 18:58:05 INFO 139767272523584] Round of batches complete
# [06/26/2023 18:58:05 INFO 139767272523584] Updated the metrics
# [06/26/2023 18:58:11 INFO 139767272523584] #quality_metric: host=algo-1, epoch=24, validation mAP <score>=(0.24267744171602817)
# [06/26/2023 18:58:11 INFO 139767272523584] #progress_metric: host=algo-1, completed 25.0 % of epochs
# ...
# [06/26/2023 19:21:57 INFO 139767272523584] #quality_metric: host=algo-1, epoch=90, batch=19 train cross_entropy <loss>=(0.8382418301173095)
# [06/26/2023 19:21:57 INFO 139767272523584] #quality_metric: host=algo-1, epoch=90, batch=19 train smooth_l1 <loss>=(0.40515256970619595)
# [06/26/2023 19:21:57 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:21:57 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:22:03 INFO 139767272523584] #quality_metric: host=algo-1, epoch=90, validation mAP <score>=(0.49275120073069995)
# [06/26/2023 19:22:03 INFO 139767272523584] Updating the best model with validation-mAP=0.49275120073069995
# [06/26/2023 19:22:03 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 19:22:03 INFO 139767272523584] #progress_metric: host=algo-1, completed 91.0 % of epochs
# #metrics {"StartTime": 1687807302.562782, "EndTime": 1687807323.786857, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 90, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 91.0, "count": 1, "min": 91, "max": 91}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:22:17 INFO 139767272523584] #quality_metric: host=algo-1, epoch=91, batch=18 train cross_entropy <loss>=(0.8371327131939783)
# [06/26/2023 19:22:17 INFO 139767272523584] #quality_metric: host=algo-1, epoch=91, batch=18 train smooth_l1 <loss>=(0.4035413731074945)
# [06/26/2023 19:22:17 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:22:17 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:22:23 INFO 139767272523584] #quality_metric: host=algo-1, epoch=91, validation mAP <score>=(0.4785258477834128)
# [06/26/2023 19:22:23 INFO 139767272523584] #progress_metric: host=algo-1, completed 92.0 % of epochs
# #metrics {"StartTime": 1687807323.7869754, "EndTime": 1687807343.7940762, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 91, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 92.0, "count": 1, "min": 92, "max": 92}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:22:38 INFO 139767272523584] #quality_metric: host=algo-1, epoch=92, batch=19 train cross_entropy <loss>=(0.8419543541842919)
# [06/26/2023 19:22:38 INFO 139767272523584] #quality_metric: host=algo-1, epoch=92, batch=19 train smooth_l1 <loss>=(0.4010628598354396)
# [06/26/2023 19:22:38 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:22:39 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:22:44 INFO 139767272523584] #quality_metric: host=algo-1, epoch=92, validation mAP <score>=(0.4823946739985742)
# [06/26/2023 19:22:44 INFO 139767272523584] #progress_metric: host=algo-1, completed 93.0 % of epochs
# #metrics {"StartTime": 1687807343.7942276, "EndTime": 1687807364.833685, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 92, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 93.0, "count": 1, "min": 93, "max": 93}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:22:59 INFO 139767272523584] #quality_metric: host=algo-1, epoch=93, batch=19 train cross_entropy <loss>=(0.8296271524982316)
# [06/26/2023 19:22:59 INFO 139767272523584] #quality_metric: host=algo-1, epoch=93, batch=19 train smooth_l1 <loss>=(0.38652669570938375)
# [06/26/2023 19:22:59 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:22:59 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:23:05 INFO 139767272523584] #quality_metric: host=algo-1, epoch=93, validation mAP <score>=(0.48888577303156266)
# [06/26/2023 19:23:05 INFO 139767272523584] #progress_metric: host=algo-1, completed 94.0 % of epochs
# #metrics {"StartTime": 1687807364.8338275, "EndTime": 1687807385.600577, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 93, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 94.0, "count": 1, "min": 94, "max": 94}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:23:20 INFO 139767272523584] #quality_metric: host=algo-1, epoch=94, batch=19 train cross_entropy <loss>=(0.8373280596216257)
# [06/26/2023 19:23:20 INFO 139767272523584] #quality_metric: host=algo-1, epoch=94, batch=19 train smooth_l1 <loss>=(0.4081639982865286)
# [06/26/2023 19:23:20 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:23:20 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:23:25 INFO 139767272523584] #quality_metric: host=algo-1, epoch=94, validation mAP <score>=(0.4639103724795667)
# [06/26/2023 19:23:25 INFO 139767272523584] #progress_metric: host=algo-1, completed 95.0 % of epochs
# #metrics {"StartTime": 1687807385.6007261, "EndTime": 1687807405.951058, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 94, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 95.0, "count": 1, "min": 95, "max": 95}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:23:39 INFO 139767272523584] #quality_metric: host=algo-1, epoch=95, batch=18 train cross_entropy <loss>=(0.8374375226395276)
# [06/26/2023 19:23:39 INFO 139767272523584] #quality_metric: host=algo-1, epoch=95, batch=18 train smooth_l1 <loss>=(0.4144519415163217)
# [06/26/2023 19:23:39 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:23:39 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:23:45 INFO 139767272523584] #quality_metric: host=algo-1, epoch=95, validation mAP <score>=(0.4741555964782031)
# [06/26/2023 19:23:45 INFO 139767272523584] #progress_metric: host=algo-1, completed 96.0 % of epochs
# #metrics {"StartTime": 1687807405.9512067, "EndTime": 1687807425.4547212, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 95, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 96.0, "count": 1, "min": 96, "max": 96}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:24:00 INFO 139767272523584] #quality_metric: host=algo-1, epoch=96, batch=19 train cross_entropy <loss>=(0.8440184975690382)
# [06/26/2023 19:24:00 INFO 139767272523584] #quality_metric: host=algo-1, epoch=96, batch=19 train smooth_l1 <loss>=(0.4086013853289169)
# [06/26/2023 19:24:00 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:24:00 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:24:06 INFO 139767272523584] #quality_metric: host=algo-1, epoch=96, validation mAP <score>=(0.48139869297161664)
# [06/26/2023 19:24:06 INFO 139767272523584] #progress_metric: host=algo-1, completed 97.0 % of epochs
# #metrics {"StartTime": 1687807425.4548488, "EndTime": 1687807446.3572936, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 96, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 97.0, "count": 1, "min": 97, "max": 97}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:24:20 INFO 139767272523584] #quality_metric: host=algo-1, epoch=97, batch=19 train cross_entropy <loss>=(0.8325631304394578)
# [06/26/2023 19:24:20 INFO 139767272523584] #quality_metric: host=algo-1, epoch=97, batch=19 train smooth_l1 <loss>=(0.3881467597601654)
# [06/26/2023 19:24:20 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:24:20 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:24:26 INFO 139767272523584] #quality_metric: host=algo-1, epoch=97, validation mAP <score>=(0.47019192831654283)
# [06/26/2023 19:24:26 INFO 139767272523584] #progress_metric: host=algo-1, completed 98.0 % of epochs
# #metrics {"StartTime": 1687807446.3574376, "EndTime": 1687807466.740028, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 97, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 98.0, "count": 1, "min": 98, "max": 98}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:24:41 INFO 139767272523584] #quality_metric: host=algo-1, epoch=98, batch=19 train cross_entropy <loss>=(0.836716180289443)
# [06/26/2023 19:24:41 INFO 139767272523584] #quality_metric: host=algo-1, epoch=98, batch=19 train smooth_l1 <loss>=(0.40369778630852415)
# [06/26/2023 19:24:41 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:24:41 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:24:47 INFO 139767272523584] #quality_metric: host=algo-1, epoch=98, validation mAP <score>=(0.4856455876498054)
# [06/26/2023 19:24:47 INFO 139767272523584] #progress_metric: host=algo-1, completed 99.0 % of epochs
# #metrics {"StartTime": 1687807466.7401867, "EndTime": 1687807487.4586859, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 98, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 99.0, "count": 1, "min": 99, "max": 99}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:25:01 INFO 139767272523584] #quality_metric: host=algo-1, epoch=99, batch=18 train cross_entropy <loss>=(0.8428095117469744)
# [06/26/2023 19:25:01 INFO 139767272523584] #quality_metric: host=algo-1, epoch=99, batch=18 train smooth_l1 <loss>=(0.4112630193633151)
# [06/26/2023 19:25:01 INFO 139767272523584] Round of batches complete
# [06/26/2023 19:25:01 INFO 139767272523584] Updated the metrics
# [06/26/2023 19:25:07 INFO 139767272523584] #quality_metric: host=algo-1, epoch=99, validation mAP <score>=(0.45689547127594377)
# [06/26/2023 19:25:07 INFO 139767272523584] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1687807487.4588346, "EndTime": 1687807507.1430953, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training", "epoch": 99, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [06/26/2023 19:25:07 WARNING 139767272523584] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [06/26/2023 19:25:07 INFO 139767272523584] Saved checkpoint to "/opt/ml/model/model_algo_1-0000.params"
# [06/26/2023 19:25:07 INFO 139767272523584] Test data is not provided.
# #metrics {"StartTime": 1687805360.4548614, "EndTime": 1687807507.7204545, "Dimensions": {"Algorithm": "AWS/Object Detection", "Host": "algo-1", "Operation": "training"}, "Metrics": {"epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "setuptime": {"sum": 4.93931770324707, "count": 1, "min": 4.93931770324707, "max": 4.93931770324707}, "totaltime": {"sum": 2147325.300216675, "count": 1, "min": 2147325.300216675, "max": 2147325.300216675}}}
#
# 2023-06-26 19:25:47 Uploading - Uploading generated training model
# 2023-06-26 19:26:07 Completed - Training job completed
# ProfilerReport-1687805054: IssuesFound
# Training seconds: 2422
# Billable seconds: 2422
# mAP tracking for job: sagemaker-soln-odbs-js-d5sl79-training-2023-06-26-18-44-14-583
# Maximum mAP: 0.492751
# CPU times: user 58.8 s, sys: 1.94 s, total: 1min
# Wall time: 43min 57s

# %% [markdown]
# ### Re-deploy and test

# %%
# host the updated model
object_detector = od_model.deploy(
    endpoint_name=f"{solution_prefix}-expanded-od-endpoint",
    model_name=f"{solution_prefix}-expanded-od-model",
    initial_instance_count=1,
    instance_type="ml.m5.xlarge",
)

# test the new model
test_model()
# Out:
# ----------!Number of detections: 0
# Number of detections: 0
# 047.American_Goldfinch,0.7377590537071228
# 047.American_Goldfinch,0.4733981788158417
# Number of detections: 2
# 036.Northern_Flicker,0.44495099782943726
# Number of detections: 1
# Number of detections: 0

# %%
# delete the new endpoint
sagemaker.Session().delete_endpoint(object_detector.endpoint_name)
